# %%
import pandas as pd

# %%
version = 'v24'

# %%
train_abst = pd.read_excel('./data/paper_train.xlsx')
train_abst = pd.DataFrame(train_abst['abstract'])

val_abst = pd.read_excel('./data/paper_val.xlsx')
val_abst = pd.DataFrame(val_abst['abstract'])

test_abst = pd.read_excel('./data/paper_test.xlsx')
test_abst = pd.DataFrame(test_abst['abstract'])



train_label = pd.read_excel('./data/rae_{}_latent_vector_train.xlsx'.format(version))
train_label = train_label.drop(['Unnamed: 0'], axis=1)

val_label = pd.read_excel('./data/rae_{}_latent_vector_val.xlsx'.format(version))
val_label = val_label.drop(['Unnamed: 0'], axis=1)

test_label = pd.read_excel('./data/rae_{}_latent_vector_test.xlsx'.format(version))
test_label = test_label.drop(['Unnamed: 0'], axis=1)

# %%
train_abst
# Out:
#                                                abstract
# 0     Modbus는 각종 자동화 장비 감시 및 제어에 전 세계적으로 널리 사용되고 있는 ...
# 1     고속철도의 출현과 함께 철도는 국내외에서 자주 사용하는 교통수단 중 하나이다. 또한...
# 2     마찰력은 일상생활에서 뉴턴 역학을 이해하는데 매우 중요한 힘임에도불구하고 많은 학생...
# 3     현재 진행형인 4차 산업혁명 사회는 기존 사회와는 여러 가지 면에서 구분되며, 그 ...
# 4     최근, 급격한 산업화로 인한 급속한 기후변화가 생태 보전 및 생물 다양성에 부정적인...
# ...                                                 ...
# 2800  딥러닝에 기반 한 인공지능과 다양한 센서기술의 발전이 빠르게 진행되면서 운전자 없이...
# 2801  본 연구는 콜버그 도덕·윤리교육의 ``정의 공동체 접근법``을 공학윤리교육에 적용하...
# 2802  인공지능 로봇이 사회적, 정서적 상호작용의 대상으로서 사람들의 일상적 공간 안으로 ...
# 2803  인공지능 로봇과 연관된 기술의 발전 속도가 빨라짐에 따라 기존에 인간에 의해서만 이...
# 2804  현재 전세계 배터리 시장은 이차전지 개발에 박차를 가하고 있는 실정이지만, 실제로 ...
#
# [2805 rows x 1 columns]

# %%
val_abst
# Out:
#                                               abstract
# 0    로지스틱 회귀분석은 통계학 등의 분야에서 예측을 위한 기술 혹은 변수 간의 상관관계...
# 1    최근에 이르러, 기계학습 및 데이터마이닝은 수많은 질병 예측 및 진단에 활용되고 있...
# 2    가상발전소 시장에 전력을 안정적으로 공급하기 위해서는 발전량에 대한 정확한 예측이 ...
# 3    문서 자동 요약은 주어진 문서로부터 주요 내용을 추출하거나 생성하는 방식으로 축약하...
# 4    최근 소프트웨어와 인공지능 교육이 점차 중요하게 다루어지면서 2019년 12월 과학...
# ..                                                 ...
# 930  인간의 특성과 관련된 측정 항목을 나타내는 생체정보는 도난이나 분실의 염려가 없으므...
# 931  제4차 산업혁명이 도래하면서 인공지능 로봇은 다양한 영화 및 드라마에서 다른 캐릭터...
# 932  초등학교 소프트웨어 교육에서는 간단한 문제해결 과정을 통하여 프로그래밍 과정을 경험...
# 933  사물인터넷(IoT) 제품 등의 보안이 허술해 각종 해킹 사고가 발생하고 있다. 보안...
# 934  이 글은 북한의 4차 산업혁명에 대한 대응전략과 추진방식, 그리고 일부 성과들을  ...
#
# [935 rows x 1 columns]

# %%
test_abst
# Out:
#                                               abstract
# 0    인류는 1800년대 1차 산업혁명을 거치면서 급격하게 변화하고 성장하였다. 약 20...
# 1    본 연구는 Deep Neural Network(DNN)을 이용하여 광주-기아 챔피언...
# 2    오늘날 기업이 급변하는 글로벌 경영 환경에 민첩하게 대응하기 위해서는 기업 구성원 ...
# 3    도시에서 홍수 피해를 방지하기 위한 침수를 예측하기 위해 본 논문에서는 딥러닝(De...
# 4    컴퓨터가 실생활에서 많이 사용됨에 따라, 악성코드(malware)를 만들어 악의적인...
# ..                                                 ...
# 930  포스트 휴머니즘의 한 갈래로서 트랜스 휴머니즘은 ‘의지적 진화’에 의한 인간의 개선...
# 931  4차 산업혁명 진전되는 인공지능 시대 노동법제 논의가 필요한 과제는 다음과 같다.첫...
# 932  본 연구는 현대 패션쇼에 나타난 포스트휴먼의 내적 특성에 관한 연구이다. 연구의 목...
# 933  제4차 산업혁명이라는 유행어가 잘 보여주는 것처럼 현대 과학기술은 사회구조 및 사고...
# 934  (연구배경 및 목적) 생활 방식 변화로 1인 가구의 증가율은 전 연령대에서 지속해서...
#
# [935 rows x 1 columns]

# %%
train_label
# Out:
#              0         1         2         3
# 0     0.000000  4.009835  2.433445  2.175651
# 1     0.330836  1.634789  0.341391  1.733869
# 2     3.204286  1.114331  7.701506  4.752499
# 3     3.116402  1.860536  2.281415  0.950183
# 4     8.971253  6.868971  3.114063  7.049732
# ...        ...       ...       ...       ...
# 2800  5.347086  4.067931  8.902108  1.609573
# 2801  1.771658  0.398778  2.420170  0.602145
# 2802  2.506279  4.002382  3.756828  1.819635
# 2803  5.189452  7.775829  7.547927  4.802491
# 2804  6.273859  4.212216  3.441089  6.629975
#
# [2805 rows x 4 columns]

# %%
val_label
# Out:
#             0         1         2         3
# 0    5.906538  2.039067  5.018996  3.587895
# 1    4.601771  4.497829  2.230905  3.394919
# 2    1.294281  4.208983  0.701540  2.775870
# 3    0.955102  2.065431  0.819086  1.747662
# 4    9.096313  2.397147  8.119800  4.275200
# ..        ...       ...       ...       ...
# 930  0.242602  5.561072  2.944644  6.759426
# 931  5.189452  7.775829  7.547928  4.802491
# 932  0.820477  2.694721  2.992634  1.547737
# 933  3.373491  0.575766  0.265189  2.548310
# 934  3.116402  1.860535  2.281415  0.950183
#
# [935 rows x 4 columns]

# %%
test_label
# Out:
#             0         1         2          3
# 0    4.314652  1.468910  1.679108   0.535186
# 1    5.671848  7.143850  6.364230  10.487472
# 2    2.450928  2.014980  0.052565   3.348545
# 3    0.242602  5.561071  2.944643   6.759424
# 4    0.366242  3.057806  0.411634   2.376442
# ..        ...       ...       ...        ...
# 930  2.109400  2.703910  4.346402   2.373624
# 931  8.510933  4.062561  6.355244   3.139387
# 932  0.888662  1.590210  3.187862   0.974992
# 933  0.000000  1.036030  1.180098   0.433684
# 934  4.660989  0.000000  2.132870   5.229282
#
# [935 rows x 4 columns]

# %%
train = pd.concat([train_abst, train_label], axis=1)
train
# Out:
#                                                abstract         0         1  \
# 0     Modbus는 각종 자동화 장비 감시 및 제어에 전 세계적으로 널리 사용되고 있는 ...  0.000000  4.009835
# 1     고속철도의 출현과 함께 철도는 국내외에서 자주 사용하는 교통수단 중 하나이다. 또한...  0.330836  1.634789
# 2     마찰력은 일상생활에서 뉴턴 역학을 이해하는데 매우 중요한 힘임에도불구하고 많은 학생...  3.204286  1.114331
# 3     현재 진행형인 4차 산업혁명 사회는 기존 사회와는 여러 가지 면에서 구분되며, 그 ...  3.116402  1.860536
# 4     최근, 급격한 산업화로 인한 급속한 기후변화가 생태 보전 및 생물 다양성에 부정적인...  8.971253  6.868971
# ...                                                 ...       ...       ...
# 2800  딥러닝에 기반 한 인공지능과 다양한 센서기술의 발전이 빠르게 진행되면서 운전자 없이...  5.347086  4.067931
# 2801  본 연구는 콜버그 도덕·윤리교육의 ``정의 공동체 접근법``을 공학윤리교육에 적용하...  1.771658  0.398778
# 2802  인공지능 로봇이 사회적, 정서적 상호작용의 대상으로서 사람들의 일상적 공간 안으로 ...  2.506279  4.002382
# 2803  인공지능 로봇과 연관된 기술의 발전 속도가 빨라짐에 따라 기존에 인간에 의해서만 이...  5.189452  7.775829
# 2804  현재 전세계 배터리 시장은 이차전지 개발에 박차를 가하고 있는 실정이지만, 실제로 ...  6.273859  4.212216
#
#              2         3
# 0     2.433445  2.175651
# 1     0.341391  1.733869
# 2     7.701506  4.752499
# 3     2.281415  0.950183
# 4     3.114063  7.049732
# ...        ...       ...
# 2800  8.902108  1.609573
# 2801  2.420170  0.602145
# 2802  3.756828  1.819635
# 2803  7.547927  4.802491
# 2804  3.441089  6.629975
#
# [2805 rows x 5 columns]

# %%
val = pd.concat([val_abst, val_label], axis=1)
val
# Out:
#                                               abstract         0         1  \
# 0    로지스틱 회귀분석은 통계학 등의 분야에서 예측을 위한 기술 혹은 변수 간의 상관관계...  5.906538  2.039067
# 1    최근에 이르러, 기계학습 및 데이터마이닝은 수많은 질병 예측 및 진단에 활용되고 있...  4.601771  4.497829
# 2    가상발전소 시장에 전력을 안정적으로 공급하기 위해서는 발전량에 대한 정확한 예측이 ...  1.294281  4.208983
# 3    문서 자동 요약은 주어진 문서로부터 주요 내용을 추출하거나 생성하는 방식으로 축약하...  0.955102  2.065431
# 4    최근 소프트웨어와 인공지능 교육이 점차 중요하게 다루어지면서 2019년 12월 과학...  9.096313  2.397147
# ..                                                 ...       ...       ...
# 930  인간의 특성과 관련된 측정 항목을 나타내는 생체정보는 도난이나 분실의 염려가 없으므...  0.242602  5.561072
# 931  제4차 산업혁명이 도래하면서 인공지능 로봇은 다양한 영화 및 드라마에서 다른 캐릭터...  5.189452  7.775829
# 932  초등학교 소프트웨어 교육에서는 간단한 문제해결 과정을 통하여 프로그래밍 과정을 경험...  0.820477  2.694721
# 933  사물인터넷(IoT) 제품 등의 보안이 허술해 각종 해킹 사고가 발생하고 있다. 보안...  3.373491  0.575766
# 934  이 글은 북한의 4차 산업혁명에 대한 대응전략과 추진방식, 그리고 일부 성과들을  ...  3.116402  1.860535
#
#             2         3
# 0    5.018996  3.587895
# 1    2.230905  3.394919
# 2    0.701540  2.775870
# 3    0.819086  1.747662
# 4    8.119800  4.275200
# ..        ...       ...
# 930  2.944644  6.759426
# 931  7.547928  4.802491
# 932  2.992634  1.547737
# 933  0.265189  2.548310
# 934  2.281415  0.950183
#
# [935 rows x 5 columns]

# %%
test = pd.concat([test_abst, test_label], axis=1)
test
# Out:
#                                               abstract         0         1  \
# 0    인류는 1800년대 1차 산업혁명을 거치면서 급격하게 변화하고 성장하였다. 약 20...  4.314652  1.468910
# 1    본 연구는 Deep Neural Network(DNN)을 이용하여 광주-기아 챔피언...  5.671848  7.143850
# 2    오늘날 기업이 급변하는 글로벌 경영 환경에 민첩하게 대응하기 위해서는 기업 구성원 ...  2.450928  2.014980
# 3    도시에서 홍수 피해를 방지하기 위한 침수를 예측하기 위해 본 논문에서는 딥러닝(De...  0.242602  5.561071
# 4    컴퓨터가 실생활에서 많이 사용됨에 따라, 악성코드(malware)를 만들어 악의적인...  0.366242  3.057806
# ..                                                 ...       ...       ...
# 930  포스트 휴머니즘의 한 갈래로서 트랜스 휴머니즘은 ‘의지적 진화’에 의한 인간의 개선...  2.109400  2.703910
# 931  4차 산업혁명 진전되는 인공지능 시대 노동법제 논의가 필요한 과제는 다음과 같다.첫...  8.510933  4.062561
# 932  본 연구는 현대 패션쇼에 나타난 포스트휴먼의 내적 특성에 관한 연구이다. 연구의 목...  0.888662  1.590210
# 933  제4차 산업혁명이라는 유행어가 잘 보여주는 것처럼 현대 과학기술은 사회구조 및 사고...  0.000000  1.036030
# 934  (연구배경 및 목적) 생활 방식 변화로 1인 가구의 증가율은 전 연령대에서 지속해서...  4.660989  0.000000
#
#             2          3
# 0    1.679108   0.535186
# 1    6.364230  10.487472
# 2    0.052565   3.348545
# 3    2.944643   6.759424
# 4    0.411634   2.376442
# ..        ...        ...
# 930  4.346402   2.373624
# 931  6.355244   3.139387
# 932  3.187862   0.974992
# 933  1.180098   0.433684
# 934  2.132870   5.229282
#
# [935 rows x 5 columns]

# %%
train.to_excel('./data/rae_{}_train.xlsx'.format(version))
val.to_excel('./data/rae_{}_val.xlsx'.format(version))
test.to_excel('./data/rae_{}_test.xlsx'.format(version))
