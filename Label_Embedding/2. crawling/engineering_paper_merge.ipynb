# %%
import pandas as pd

# %%
engin_dl = pd.read_excel('./engin_dl.xlsx')
engin_dl
# Out:
#                                                   title  \
# 0     Deep Learning in Genomic and Medical Image Dat...
# 1        어린이집 영역배치 자동 대안생성을 위한 Deep Learning의 활용에 관한 연구
# 2     BERT Transformer와 Deep Learning을 활용한 전이학습 효과 검...
# 3     딥러닝(Deep Learning)을 이용한 GMA 용접에서 이면비드 생성 유무 판단...
# 4     임베디드 시스템에서 사용 가능한 적응형 MFCC와 Deep Learning 기반의 ...
# ...                                                 ...
# 4834                       인공지능을 이용한 법률전문가 시스템의 동향 및 구상
# 4835     기술평가를 위한평가 참조정보 생성 방안에 관한 연구 : 기술적 속성 유사성 관점에서
# 4836  정지궤도 기상위성 및 수치예보모델 융합을 통한 Multi-task Learning ...
# 4837               일상생활 신체활동 측정을 위한 스마트폰기반 검사도구의수렴타당도검증
# 4838  성범죄 사건에 대한 포털 뉴스 기사 및 사용자 의견 데이터 분석: n번방 사건을 중심으로
#
#                                                  author  \
# 0     ( Ning Yu )\r\n\t\t\t\t\t\t\t\r\n             ...
# 1                                                   이윤길
# 2                                                   전영호
# 3     김민석(Min Seok Kim)\r\n\t\t\t\t\t\t\t\r\n       ...
# ...

# %%
engin_ml = pd.read_excel('./engin_ml.xlsx')
engin_ml
# Out:
#                                                   title  \
# 0         PSO 알고리즘을 이용한 퍼지 Extreme Learning Machine 최적화
# 1              Extreme Learning Machine 기반 퍼지 패턴 분류기 설계
# 2            Lifelong Machine Learning 기반 스팸 메시지 필터링 방법
# 3     행정-정책 의사결정에서 머신러닝(machine learning) 방법론 도입의 정책...
# 4     Machine Learning based Prediction of The Value...
# ...                                                 ...
# 4423                         새로운 자극제시방법을 사용한 P300 문자입력기
# 4424                  영화 <그녀>를 통해 본 인공지능과 인간의 공존이 주는 의미
# 4425                 부분 구문 분석 결과에 기반한 두 단계 부분 의미 분석 시스템
# 4426                     영화 시나리오와 영화촬영기법을 이용한 감정 예측 시스템
# 4427                               나이지리아 초·중학교 기술교육의 탐색
#
#                                                  author  \
# 0     노석범(Seok-Beom Roh)\r\n\t\t\t\t\t\t\t\r\n      ...
# 1     안태천(Tae-Chon Ahn)\r\n\t\t\t\t\t\t\t\r\n       ...
# 2     안연선\r\n\t\t\t\t\t\t\t\r\n                     ...
# 3     김병조\r\n\t\t\t\t\t\t\t\r\n                     ...
# ...

# %%
engin_ee = pd.read_excel('./engin_ee.xlsx')
engin_ee
# Out:
#                                                   title  \
# 0     education, MSC, and engineering design at Chos...
# 1     Analysis of Elementary and Secondary School Te...
# 2                  기초적 공학교육을 위한 Reverse-engineering 교수법
# 3         Novel Engineering을 적용한 SW융합 안전교육 프로그램 개발 및 적용
# 4     Exploring the Exemplary STEAM Education in the...
# ...                                                 ...
# 5005    Eye tracking 기법을 적용한 AAC 중재가 지체중복 장애학생에게 미치는 효과
# 5006                            기술적 관점에서 바라본 사진사에 대한 고찰
# 5007              테크놀로지를 활용한 대학 수업에서 중국국제학생 자오밍의 수학학습과정
# 5008                 중학교 학급유형에 따른 체육수업의 내적동기와 수업만족도의 관계
# 5009                 중학교 학급유형에 따른 체육수업의 내적동기와 수업만족도의 관계
#
#                                                  author  \
# 0     고현선\r\n\t\t\t\t\t\t\t\r\n                     ...
# 1     김영민\r\n\t\t\t\t\t\t\t\r\n                     ...
# 2                                    김남호 ( Nam Ho Kim )
# 3                                                   홍지연
# ...

# %%
engin_friction = pd.read_excel('./engin_friction.xlsx')
engin_friction
# Out:
#                                                   title  \
# 0     Evaluation of Friction Properties According to...
# 1     Engine Oil Jet System이 Engine Friction에 미치는 영향...
# 2     General Paper : Analyses of Influence of Frict...
# 3     Research Papers : Elastomers and Composites ; ...
# 4     A Study on Adhesion Friction Characteristics o...
# ...                                                 ...
# 2903                                 개단말뚝의 폐색효과 영향인자 분석
# 2904                              점토지반에 설치된 말뚝의 하중전이 특성
# 2905    동재하시험을 통한 선단이 암반에 근입된 초고강도 매입 PHC 말뚝의 지지력 특성 분석
# 2906                      중구경 현장타설말뚝의 지지력 특성에 관한 실험적 연구
# 2907                 수치해석을 이용한 점성토 지반에 설치된 버켓기초의 지지력 분석
#
#                                                  author  \
# 0     Chun Young Park\r\n\t\t\t\t\t\t\t\r\n         ...
# 1                                       민선기(Sun-Ki Min)
# 2     김철 ( Cheol Kim )\r\n\t\t\t\t\t\t\t\r\n        ...
# 3     ( Xiang Xu Li )\r\n\t\t\t\t\t\t\t\r\n         ...
# ...

# %%
engin_IoT = pd.read_excel('./engin_IoT.xlsx')
engin_IoT
# Out:
#                                                   title  \
# 0                                        사물인터넷 보안 기술 분석
# 1                                 사물인터넷 산업의 경제적 파급효과 분석
# 2                 사물인터넷을 위한 신경망 기반의 지능형 액세스 포인트 시스템의 구현
# 3                           세부 동작 기반 사물인터넷 서비스 분류 기법 개발
# 4                        사물인터넷을 위한 침입탐지 및 자가 치료 시스템의 설계
# ...                                                 ...
# 4229                                             혁신과 규제
# 4230  수면무호흡 환자의 양압기 제품서비스디자인 개발에 대한 서비스 제공자와 수혜자가 느끼...
# 4231  가임여성 Interactive PHR기반 라이프사이클 개선을 위한 스마트 패어런팅 ...
# 4232                     사회연결망 분석원리의 범죄 수사상 활용방안에 관한 연구
# 4233                               실시간 냉동컨테이너 관리 시스템 개발
#
#                                                  author  \
# 0                                                   이호태
# 1     정우수 ( Woo-soo Jeong )\r\n\t\t\t\t\t\t\t\r\n   ...
# 2     이영찬\r\n\t\t\t\t\t\t\t\r\n                     ...
# 3     조정훈\r\n\t\t\t\t\t\t\t\r\n                     ...
# ...

# %%
engin_인공지능 = pd.read_excel('./engin_인공지능.xlsx')
engin_인공지능
# Out:
#                                                   title  \
# 0                                 인공지능 기술분석을 위한 베이지안 추론
# 1     텍스트 마이닝 기법을 활용한 인공지능 기술개발 동향 분석 연구: 깃허브 상의 오픈 ...
# 2                           딥러닝의 변수 중요도를 이용한 인공지능 기술 분석
# 3                              심볼릭 인공지능을 위한 R 심볼릭 데이터분석
# 4              소셜 미디어 상에서의 인공지능 관련 사회적 여론에 대한다 범주 감성 분석
# ...                                                 ...
# 3009          한국형사법학 60년의 회고와 전망 -형법각론분야: 개인적 법익에 대한 죄-
# 3010                       비교법적, 행동주의적 관점에서 본 민사소송의 증명도
# 3011            허위조작정보(소위 ‘가짜뉴스’) 규제에 대한 헌법적 문제점에 관한 연구
# 3012                ICT 융복합 시설설치의 원스톱 행정체제 도입에 관한 법적 검토
# 3013                               포스트휴먼 시대의 로봇과 인간의 윤리
#
#                                                  author  \
# 0     최준혁(Junhyeog Choi)\r\n\t\t\t\t\t\t\t\r\n      ...
# 1     정지선\r\n\t\t\t\t\t\t\t\r\n                     ...
# 2     김승환(Seungwhan Kim)\r\n\t\t\t\t\t\t\t\r\n      ...
# 3                                      전성해(Sunghae Jun)
# ...

# %%
paper_all = pd.concat([engin_dl, engin_ml, engin_ee, engin_friction, engin_IoT, engin_인공지능], axis=0)
paper_all
# Out:
#                                                   title  \
# 0     Deep Learning in Genomic and Medical Image Dat...
# 1        어린이집 영역배치 자동 대안생성을 위한 Deep Learning의 활용에 관한 연구
# 2     BERT Transformer와 Deep Learning을 활용한 전이학습 효과 검...
# 3     딥러닝(Deep Learning)을 이용한 GMA 용접에서 이면비드 생성 유무 판단...
# 4     임베디드 시스템에서 사용 가능한 적응형 MFCC와 Deep Learning 기반의 ...
# ...                                                 ...
# 3009          한국형사법학 60년의 회고와 전망 -형법각론분야: 개인적 법익에 대한 죄-
# 3010                       비교법적, 행동주의적 관점에서 본 민사소송의 증명도
# 3011            허위조작정보(소위 ‘가짜뉴스’) 규제에 대한 헌법적 문제점에 관한 연구
# 3012                ICT 융복합 시설설치의 원스톱 행정체제 도입에 관한 법적 검토
# 3013                               포스트휴먼 시대의 로봇과 인간의 윤리
#
#                                                  author  \
# 0     ( Ning Yu )\r\n\t\t\t\t\t\t\t\r\n             ...
# 1                                                   이윤길
# 2                                                   전영호
# 3     김민석(Min Seok Kim)\r\n\t\t\t\t\t\t\t\r\n       ...
# ...

# %%
paper_all = paper_all.reset_index(drop=True)
paper_all
# Out:
#                                                    title  \
# 0      Deep Learning in Genomic and Medical Image Dat...
# 1         어린이집 영역배치 자동 대안생성을 위한 Deep Learning의 활용에 관한 연구
# 2      BERT Transformer와 Deep Learning을 활용한 전이학습 효과 검...
# 3      딥러닝(Deep Learning)을 이용한 GMA 용접에서 이면비드 생성 유무 판단...
# 4      임베디드 시스템에서 사용 가능한 적응형 MFCC와 Deep Learning 기반의 ...
# ...                                                  ...
# 24428          한국형사법학 60년의 회고와 전망 -형법각론분야: 개인적 법익에 대한 죄-
# 24429                       비교법적, 행동주의적 관점에서 본 민사소송의 증명도
# 24430            허위조작정보(소위 ‘가짜뉴스’) 규제에 대한 헌법적 문제점에 관한 연구
# 24431                ICT 융복합 시설설치의 원스톱 행정체제 도입에 관한 법적 검토
# 24432                               포스트휴먼 시대의 로봇과 인간의 윤리
#
#                                                   author  \
# 0      ( Ning Yu )\r\n\t\t\t\t\t\t\t\r\n             ...
# 1                                                    이윤길
# 2                                                    전영호
# ...

# %%
paper_all.to_excel('./engineering_paper_all.xlsx')
