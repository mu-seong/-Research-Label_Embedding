# %%
import pandas as pd

# %%
_1 = pd.read_excel('./1_대학생.xlsx')
_1
# Out:
#                                                  title  \
# 0                         대학생의 성희롱 및 성평등 인식 수준 및 영향 요인
# 1           대학급식의 친환경 농산물 이용에 대한 전남ㆍ경남지역 대학생의 가격민감성 비교
# 2                        대학생의 건강관련 생활태도와 모유수유의지에 관한 연구
# 3      대학생의 영양표시 확인 여부에 따른 영양표시에 대한 지식, 인식 및 유용성 자각 비교
# 4                 대학생이 지각한 가족탄력성과 한국판 동적가족화 반응특성 관계 연구
# ..                                                 ...
# 351          도시림 산책이 심리적 안정에 미치는 영향 -일본 신주쿠교엔 현장실험 결과-
# 352         사용성 평가(Usability Test)를 통한 휠체어 사용자용 화장실 개발
# 353                           쇼윈도우 디스플레이가 구매의도에 미치는 영향
# 354  전문대학 학사학위 전공심화과정 학습자의 학습동기와 등록 유인가, 자기효능감, 목표지...
# 355                  간호대학 4학년생이 지각한 간호사로의 역할 이행과 영향 요인
#
#                                                 author  \
# 0    이영란 ( Young Ran Lee )\r\n\t\t\t\t\t\t\t\r\n   ...
# 1    이소정(So-Jung Lee)\r\n\t\t\t\t\t\t\t\r\n        ...
# 2    이조윤 ( Jo Yoon Lee )\r\n\t\t\t\t\t\t\t\r\n     ...
# 3    이경애(Kyoung-Ae Lee)\r\n\t\t\t\t\t\t\t\r\n      ...
# ...

# %%
_2 = pd.read_excel('./2_우울.xlsx')
_2
# Out:
#                                                  title  \
# 0                      우울장애 환자에서 항우울제 치료가 삶의 질에 미치는 영향
# 1         우울취약성과 대인관계문제의 관계에서 능동적, 회피/분산적 정서조절양식의 매개효과
# 2    우울을 동반하거나 동반하지 않은 강박증상군과 우울증상군의 변별\r\n\t\t\t \...
# 3           기혼여성의 우울유무에 따른 좋아하는 날씨(FKW) 그림의 반응 특성 차이연구
# 4                          중년여성의 부부친밀감, 우울과 갱년기 증상의 관계
# ..                                                 ...
# 453  산후조리원 이용여부에 따른 초산모의 신체적, 심리적 건강상태 및 모성역할적응의 변화...
# 454     재택 치매환자의 정신행동증상 관리와 보호자 부담감소를 위한 맞춤형활동프로그램의 효과
# 455       오감자극 원예활동 프로그램이 저소득가정 아동의 집중력 및 문제행동에 미치는 영향
# 456                     지하철 기관사의 외상후스트레스장애 증상에 대한 중재효과
# 457                        산림활동을 통한 보호대상아동 자립 정서 변화 분석
#
#                                                 author  \
# 0    황성기(Sung-Ki Hwang)\r\n\t\t\t\t\t\t\t\r\n      ...
# 1    박송이\r\n\t\t\t\t\t\t\t\r\n                     ...
# 2    신지연\r\n\t\t\t\t\t\t\t\r\n                     ...
# 3    강수현\r\n\t\t\t\t\t\t\t\r\n                     ...
# ...

# %%
_3 = pd.read_excel('./3_China.xlsx')
_3
# Out:
#                                                  title  \
# 0    Pathophysiologic Findings of Irritable Bowel S...
# 1    치매환자의 두침(頭鍼)치료에 대한 최신 임상연구 동향 -CAJ (China Acad...
# 2    Research Articles : Spatial Pattern of Larix g...
# 3    Adsorptive Granulocyte and Monocyte Apheresis ...
# 4    ORiginal Article : Association of IL28B Genoty...
# ..                                                 ...
# 316                 지구온난화에 따른 상수리나무와 굴참나무의 생육반응에 관한 연구
# 317  실천공학교육관련 : 비 HCI 전공자들을 대상으로 한 Nielsen의 Usabili...
# 318                    환경모니터링을 위한 집비둘기 깃털의 중금속 축적특성 연구
# 319  원저 : 2-peg Type의 옥스퍼드 슬관절 부분치환술의 단기 임상 추시 결과: ...
# 320                 어린 아동을 둔 취업모의 양육부담감 경험에 대한 현상학적 연구
#
#                                                 author  \
# 0    ( Li Kun Zhong )\r\n\t\t\t\t\t\t\t\r\n        ...
# 1    이고은 ( Go Eun Lee )\r\n\t\t\t\t\t\t\t\r\n      ...
# 2    ( Guang Ze Jin )\r\n\t\t\t\t\t\t\t\r\n        ...
# 3    ( Ya-min Lai )\r\n\t\t\t\t\t\t\t\r\n          ...
# ...

# %%
_4 = pd.read_excel('./4_Depression.xlsx')
_4
# Out:
#                                                  title  \
# 0    The effect of depression and health-related qu...
# 1    Original Articles : Assessment of Quality of L...
# 2                             산후우울의 영향요인과 모성 정체성과의 관련성
# 3           한국 다낭난소증후군 환자의 우울증과 식품 및 영양소 섭취, 식습관과의 관련성
# 4                            한국 여자 중학생의 우울에 영향을 미치는 요인
# ..                                                 ...
# 644   원저 : 소화기 ; 비미란성 위식도역류질환에서 비심인성 흉통의 임상적 특징과 치료 반응
# 645     일부 VDT작업 사무직 근로자에서 직무스트레스와 신체부위별 근골격계질환 증상의 차이
# 646                      그린인테리어 주거공간에 대한 인간의 심리적 효과 분석
# 647             원예활동이 중학생 자녀를 둔 어머니의 스트레스와 행복감에 미치는 영향
# 648                               노인의 성별에 따른 자살생각 영향요인
#
#                                                 author  \
# 0    ( Yon Su Kim )\r\n\t\t\t\t\t\t\t\r\n          ...
# 1    ( Hun Lee )\r\n\t\t\t\t\t\t\t\r\n             ...
# 2    정연이 ( Jung Yoen Ti )\r\n\t\t\t\t\t\t\t\r\n    ...
# 3    김승현(Kim Seung Hyun)\r\n\t\t\t\t\t\t\t\r\n     ...
# ...

# %%
_5 = pd.read_excel('./5_자기효능감.xlsx')
_5
# Out:
#                                                  title  \
# 0        영아 보육교사의 상해예방을 위한 감독과 자기 효능감 및 직무 스트레스의 관계 연구
# 1    대학생의 진로준비행동과 진로불확실성, 자기개념명확성, 진로결정자기효능감, 진로통찰력...
# 2                             미술치료사의 자의식과 자기효능감에 관한 연구
# 3        만성 폐쇄성 폐질환 환자의 증상경험, 자기효능감, 우울과 약물복용 이행 간의 관계
# 4    창의적 문제해결(CPS)모형을 적용한 집단미술치료가 미혼모의 자기효능감과 문제해결력...
# ..                                                 ...
# 167                             대학생 흡연자의 금연 준비단계 관련 요인
# 168                   기업체 종사자의 변화에 대한 준비성과 관련 변인의 인과분석
# 169                                 여성노인의 양생행위 경로모형 분석
# 170         범이론 모형을 적용한 고혈압 환자 약물순응 중재 프로그램 개발 및 적용 효과
# 171                     다수준 건강증진 모형에 기반 한 건강증진 프로그램 효과
#
#                                                 author  \
# 0                                  김혜금 ( Hye Gum Kim )
# 1                                      곽미선(Misun Kwak)
# 2    김채연\r\n\t\t\t\t\t\t\t\r\n                     ...
# 3    박수민\r\n\t\t\t\t\t\t\t\r\n                     ...
# ...

# %%
_6 = pd.read_excel('./6_인공지능.xlsx')
_6
# Out:
#                                                 title  \
# 0                이중외피 건물의 개구부 및 난방설비 제어를 위한 인공지능망의 적용
# 1                         인공지능기법을 이용한 외환위기 조기경보시스템 구축
# 2              인공지능 기반 사람의 자세 분류를 이용한 두 바퀴 로봇의 움직임 제어
# 3            인공지능을 이용한 파프리카 실내 양액 재배 시 발생하는 병해충 자동 검출
# 4                    인공지능 피난유도설비 적용에 따른 최적 대피시뮬레이션 연구
# 5     [인공지능, 신경망 및 퍼지시스템] 클라우드 컴퓨팅에 적합한 LDPC 부호 복제 기법
# 6                 영어발음 향상을 위한 실시간 인공지능 입모양 인식 프로그램 개발
# 7                 인공신경망을 이용한 지하채광 확정선외 혼입 예측과 분석 사례연구
# 8                                   지능을 이용한 온실 제어 시스템
# 9    도로기상정보시스템(RWIS)과 차량검지기(VDS) 자료를 이용한 강우수준별 통행속도예측
# 10                  게임이론 관점에서 본 개인의 배반이 집단 이익에 미치는 영향
# 11                    게임 캐릭터의 전술적 행동을 위한 위치 평가 함수의 학습
# 12  Particle Swarm Optimization을 이용한 공동주택의 공사비 예측에...
# 13                 인간의 인지능력 기반의 행동특성이 반영된 분산대피에 관한 연구
# 14                      복수의 이미지를 합성하여 사용하는 캡차의 안전성 검증
# 15               게임적 요소와 강화학습의 차용을 통한 디지털아트 구현에 관한 연구
#
# ...

# %%
_7 = pd.read_excel('./7_청소년.xlsx')
_7
# Out:
#                                                  title  \
# 0                        청소년용 정신화 프로그램의 학생정신건강 증진효과 평가
# 1                                  소아청소년 양극성 장애의 임상 경과
# 2                      소아청소년 우울증에서의 환경적 위험 인자들과 임상적 의미
# 3    청소년정서행동발달검사 표준화연구 자료를 활용한 학교폭력 피해 전국유병률 및 관련요인 조사
# 4               소아청소년 집단에서 집단 따돌림의 유병률과 이와 관련된 정신병리 현상
# ..                                                 ...
# 404           원예치료가 여자 소년원생의 자아존중감, 몰입, 행복감 향상에 미치는 영향
# 405  집단미술치료가 저소득층 여성의 우울과 스트레스 감소에 미치는 효과연구\r\n\t\t...
# 406                저신장 소아에서 성장호르몬 치료가 두개안면필 성장에 미치는 영향
# 407         Treacher Collins 증후군 환아의 기관 삽관 시 마우스가드의 활용
# 408              작업치료사 핵심직무 분석과 경력과 치료 분야에 따른 직무 차이 비교
#
#                                                 author  \
# 0    문수진\r\n\t\t\t\t\t\t\t\r\n                     ...
# 1    강나리\r\n\t\t\t\t\t\t\t\r\n                     ...
# 2                                                  이문수
# 3    방수영\r\n\t\t\t\t\t\t\t\r\n                     ...
# ...

# %%
_8 = pd.read_excel('./8_Satisfaction.xlsx')
_8
# Out:
#                                                   title  \
# 0     Analysis of Reward and Royalty Programs Affect...
# 1     Development of Customer Satisfaction Quality I...
# 2                연구논문 : 여중, 고생들의 베이스 메이크업 시 만족도와 심리적 변인
# 3                       초등학생 급식 만족과 조리종사자 직무 만족간의 관계 분석
# 4                   아파트 거주자의 변인에 따른 주거환경 만족도의 차이에 대한 연구
# ...                                                 ...
# 1037    원저 : 혈액종양 : 암 환자에서 염산히드로모르폰 서방정의 효과와 내약성에 대한 연구
# 1038                       연구보문 : 독일 종자은행의 식물유전자원 관리 체계
# 1039  광주 · 전남 일부 지역 중학생들의 BMI 수준에 따른 식행동, 체형인식 및 체중조...
# 1040                       여성 결혼이민자 남편의 스트레스, 자존감 및 무력감
# 1041             원예활동이 중학생 자녀를 둔 어머니의 스트레스와 행복감에 미치는 영향
#
#                                                  author  \
# 0     Soo Young Choi\r\n\t\t\t\t\t\t\t\r\n          ...
# 1     Dong-Hyuk Kim\r\n\t\t\t\t\t\t\t\r\n           ...
# 2     이명희 ( Myung Hee Lee )\r\n\t\t\t\t\t\t\t\r\n   ...
# 3     허한나 ( Han Na Heu )\r\n\t\t\t\t\t\t\t\r\n      ...
# ...

# %%
_9 = pd.read_excel('./8_질적_연구.xlsx')
_9
# Out:
#                                                  title  \
# 0                                   모유수유모의 수유경험에 대한 연구
# 1                                 뇌졸중 노인 환자의 원예요법 체험연구
# 2    미술치료 석사 과정생의 미술치료 체험연구\r\n\t\t\t \t\r\n\t\t\t ...
# 3                                   산업디자인의 질적 연구 특성 고찰
# 4                   폭력가정의 아동과 어머니를 위한 집단미술활동에 대한 질적 연구
# ..                                                 ...
# 277      독일식 양안시 검사법 MKH에 따른 주시시차 교정 전후 입체지각 반응 속도의 변화
# 278                                배 품종별 꽃받침 탈리와 유전 양식
# 279                           ISSR 마커를 이용한 달래와 산달래의 분류
# 280                        대구 · 경북지역 학교급식소 오븐 사용 효과 평가
# 281    향상된 미생물 유전체 주석 처리를 위한 단백질 발현 유전자 및 위유전자 판별 알고리즘
#
#                                                 author  \
# 0    백경선(Baek Kyoung Seon)\r\n\t\t\t\t\t\t\t\r\n   ...
# 1    김미정(Kim Mi Jung)\r\n\t\t\t\t\t\t\t\r\n        ...
# 2    홍혜정(Hong Hea Jung)\r\n\t\t\t\t\t\t\t\r\n      ...
# 3    이주명(Rhi Joomyung)\r\n\t\t\t\t\t\t\t\r\n       ...
# ...

# %%
_10 = pd.read_excel('./10_빅데이터.xlsx')
_10
# Out:
#                                                 title  \
# 0                       항공 통신 기술 분야 : 빅 데이터의 품질 요소 제안
# 1                         중소기업에서 정부 3.0기반의 빅 데이터 활용정책
# 2                 빅 데이터의 새로운 고객 가치와 비즈니스 창출을 위한 대응 전략
# 3                           신(新)기술(빅데이터) 등장과 개인정보의 보호
# 4                             공간 빅데이터 핵심서비스 선정에 관한 연구
# 5                빅데이터를 활용한 휴양림 이용객현황과 인터넷 검색어의 상관관계분석
# 6       맵리듀스에서 빅데이터 분석을 위한 다중 Group-by 질의의 효율적인 처리 기법
# 7              빅데이터 분석 기반의 오피니언 마이닝을 이용한 정보화 사업 평가 분석
# 8                          SNS 빅 데이터를 이용한 산림치유의 인식 분석
# 9                 빅데이터 분석 도구 R을 활용한 효율적인 특허 검색에 관한 연구
# 10  가변 윈도우 기법을 적용한 통계적 공정 제어와 퍼지추론 기법을 이용한 소프트웨어 성...
# 11   보건의료 빅데이터를 이용한 전문재활치료 건강보험수가 현황 분석: ICF 모델을 중심으로
# 12                       MongoDB에 대한 디지털 포렌식 조사 기법 연구
# 13                   노인근로자의 직무특성 및 여가활동참여가 건강에 미치는 영향
# 14        건강보험급여 기반의 작업치료 진료행위 현황에 관한 연구 : 2011~2015년
# 15                          지속가능한 미래형 스마트교육 시스템 구축 방안
# ...

# %%
paper_all = pd.concat([_1, _2, _3, _4, _5, _6, _7, _8, _9, _10], axis=0)
paper_all
# Out:
#                                                 title  \
# 0                        대학생의 성희롱 및 성평등 인식 수준 및 영향 요인
# 1          대학급식의 친환경 농산물 이용에 대한 전남ㆍ경남지역 대학생의 가격민감성 비교
# 2                       대학생의 건강관련 생활태도와 모유수유의지에 관한 연구
# 3     대학생의 영양표시 확인 여부에 따른 영양표시에 대한 지식, 인식 및 유용성 자각 비교
# 4                대학생이 지각한 가족탄력성과 한국판 동적가족화 반응특성 관계 연구
# ..                                                ...
# 13                   노인근로자의 직무특성 및 여가활동참여가 건강에 미치는 영향
# 14        건강보험급여 기반의 작업치료 진료행위 현황에 관한 연구 : 2011~2015년
# 15                          지속가능한 미래형 스마트교육 시스템 구축 방안
# 16                     No Disk System 환경에서의 사용자 행위 분석
# 17  중소기업을 위한 프라이빗 클라우드 인프라 기반 하둡 클러스터의 기본 프로토타입 설계...
#
#                                                author  \
# 0   이영란 ( Young Ran Lee )\r\n\t\t\t\t\t\t\t\r\n   ...
# 1   이소정(So-Jung Lee)\r\n\t\t\t\t\t\t\t\r\n        ...
# 2   이조윤 ( Jo Yoon Lee )\r\n\t\t\t\t\t\t\t\r\n     ...
# 3   이경애(Kyoung-Ae Lee)\r\n\t\t\t\t\t\t\t\r\n      ...
# ...

# %%
paper_all = paper_all.reset_index(drop=True)
paper_all
# Out:
#                                                   title  \
# 0                          대학생의 성희롱 및 성평등 인식 수준 및 영향 요인
# 1            대학급식의 친환경 농산물 이용에 대한 전남ㆍ경남지역 대학생의 가격민감성 비교
# 2                         대학생의 건강관련 생활태도와 모유수유의지에 관한 연구
# 3       대학생의 영양표시 확인 여부에 따른 영양표시에 대한 지식, 인식 및 유용성 자각 비교
# 4                  대학생이 지각한 가족탄력성과 한국판 동적가족화 반응특성 관계 연구
# ...                                                 ...
# 3718                   노인근로자의 직무특성 및 여가활동참여가 건강에 미치는 영향
# 3719        건강보험급여 기반의 작업치료 진료행위 현황에 관한 연구 : 2011~2015년
# 3720                          지속가능한 미래형 스마트교육 시스템 구축 방안
# 3721                     No Disk System 환경에서의 사용자 행위 분석
# 3722  중소기업을 위한 프라이빗 클라우드 인프라 기반 하둡 클러스터의 기본 프로토타입 설계...
#
#                                                  author  \
# 0     이영란 ( Young Ran Lee )\r\n\t\t\t\t\t\t\t\r\n   ...
# 1     이소정(So-Jung Lee)\r\n\t\t\t\t\t\t\t\r\n        ...
# 2     이조윤 ( Jo Yoon Lee )\r\n\t\t\t\t\t\t\t\r\n     ...
# 3     이경애(Kyoung-Ae Lee)\r\n\t\t\t\t\t\t\t\r\n      ...
# ...

# %%
paper_all.to_csv('./paper_all.csv')

# %%
pd.read_csv('./paper_all.csv')
# Out:
#       Unnamed: 0                                              title  \
# 0              0                       대학생의 성희롱 및 성평등 인식 수준 및 영향 요인
# 1              1         대학급식의 친환경 농산물 이용에 대한 전남ㆍ경남지역 대학생의 가격민감성 비교
# 2              2                      대학생의 건강관련 생활태도와 모유수유의지에 관한 연구
# 3              3    대학생의 영양표시 확인 여부에 따른 영양표시에 대한 지식, 인식 및 유용성 자각 비교
# 4              4               대학생이 지각한 가족탄력성과 한국판 동적가족화 반응특성 관계 연구
# ...          ...                                                ...
# 3718        3718                   노인근로자의 직무특성 및 여가활동참여가 건강에 미치는 영향
# 3719        3719        건강보험급여 기반의 작업치료 진료행위 현황에 관한 연구 : 2011~2015년
# 3720        3720                          지속가능한 미래형 스마트교육 시스템 구축 방안
# 3721        3721                     No Disk System 환경에서의 사용자 행위 분석
# 3722        3722  중소기업을 위한 프라이빗 클라우드 인프라 기반 하둡 클러스터의 기본 프로토타입 설계...
#
#                                                  author  \
# 0     이영란 ( Young Ran Lee )\r\n\t\t\t\t\t\t\t\r\n   ...
# ...
