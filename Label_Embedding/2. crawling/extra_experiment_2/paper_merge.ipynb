# %%
import pandas as pd

# %%
_1 = pd.read_excel('./1_대학생.xlsx')
_1
# Out:
#                                                    title  \
# 0      대학생 안보의식 제고 방안 연구\r\n\t\t\t \t\r\n\t\t\t \t\r\...
# 1      자살 보도량과 심리적 변인이 대학생의 자살 의도에 미치는 영향에 관한 연구\r\n\...
# 2      장애 대학생의 지각된 스트례스와 삶의 만족간의 통합성의 매개효과분석\r\n\t\t\...
# 3      대학생 광고공모전이 광고업계 취업에 미치는 영향\r\n\t\t\t \t\r\n\t\...
# 4      개인 및 대학특성이 대학생활을 통해 형성하는 사회자본에 미치는 영향과 그 효과\r\...
# ...                                                  ...
# 16135                       국가대표 학생선수 진천선수촌 이동수업 운영 방안연구
# 16136            보건교육 전·후 대학 신입생과 재학생 간 건강증진행위, 자기효능감 비교
# 16137                           원격대학 이주민 재학생의 학업적응 과정 분석
# 16138          거절 민감성이 높은 사람들에 대한 단기 마음챙김 개입의 사회불안 완화 효과
# 16139  전문직으로서의 의사 직업윤리: 사회적 직관주의 이론을 바탕으로 한 일개대학 의학전문...
#
#                                                   author  \
# 0                                                    김규남
# 1      이정기(Jeong-Ki Lee)\r\n\t\t\t\t\t\t\t\r\n       ...
# 2                                                    박지순
# 3      차유철\r\n\t\t\t\t\t\t\t\r\n                     ...
# 4      박희진\r\n\t\t\t\t\t\t\t\r\n                     ...
# ...                                                  ...
# 16135  하웅용\r\n\t\t\t\t\t\t\t\r\n                     ...
# 16136  김성수\r\n\t\t\t\t\t\t\t\r\n                     ...
# 16137                                           은혜경(殷惠瓊)
# 16138  남기석\r\n\t\t\t\t\t\t\t\r\n                     ...
# 16139  박소연\r\n\t\t\t\t\t\t\t\r\n                     ...
#
#                                                     book  year  \
# 0                융합보안 논문지(Convergence security journal )  2013
# 1                                             방송과 커뮤니케이션  2011
# 2                                             특수교육재활과학연구  2015
# 3               광고학연구(The Korean Journal of Advertising)  2013
# 4                      한국교육(Journal of Korean Education)  2015
# ...                                                  ...   ...
# 16135                             스포츠사이언스(Sport Science)  2020
# 16136           디지털융복합연구(Journal of Digital Convergence)  2014
# 16137                아시아교육연구(Asian journal of education)  2018
# 16138  人間理解(Journal of Human Understanding and Counse...  2019
# 16139                                          한국의료윤리학회지  2014
#
#                                                  keyword  \
# 0      National security\r\n\t\t\t\t\t\t\t\t\r\n\t\t\...
# 1      자살 보도\r\n\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\r\...
# 2      삶의 만즉， 통합성\r\n\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t...
# 3                                                    325
# 4      대학생활 적응\r\n\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\...
# ...                                                  ...
# 16135  national student athlete\r\n\t\t\t\t\t\t\t\t\r...
# 16136  보건교육\r\n\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\r\n...
# 16137  원격대학\r\n\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\r\n...
# 16138  거절 민감성\r\n\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\r...
# 16139  professional\r\n\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t...
#
#                                             abstract_kor  \
# 0      국가안보란 국가와 국민의 생명과 재산을 적으로부터 지키는 것이며, 안보의식은 국민이...
# 1      최근 대학생의 자살 문제가 사회적 이슈로 부각되었다. 이에 이번 연구에서는 대학생의...
# 2      The purpose of this study was to investigate a...
# 3      취업난이 심각한 상황에서 광고업계 취업에 공모전 수상경력이 꼭 필요한 사항이라는 인...
# 4      Purpose: The purpose of this study is to explo...
# ...                                                  ...
# 16135  본 연구는 다양한 연구방법을 활용하여 진천선수촌 이동수업의 효율적인 시스템과 진행방...
# 16136  본 연구는 충청지역 1개 대학에서 교양교과목으로 보건교육 과목을 수강한 기숙사 신입...
# 16137  본 연구의 목적은 국내 원격대학에 입학한 이주민 학생들의 학업적응 과정을 분석하는 ...
# 16138  This study focused on mindfulness as the inter...
# 16139  This study was designed to determine whether o...
#
#                                             abstract_eng
# 0      요약\r\n\t\t\t\t\t\r\n\t\t\t\t\t ABSTRACT\r\n\t\...
# 1      Recently suicide among college students has em...
# 2      본 연구는 장애 대학생의 지각된 스트레스와 삶의 만족 간의 관계에서 통합성이 갖는 ...
# 3      요약\r\r\n\t\t\t\t\t\r\n\t\t\t\t\t 1. 연구배경 및 목적\...
# 4      본 연구는 우리나라 초기 성인들의 대학생활을 사회자본이론을 활용하여 이해하고자 하는...
# ...                                                  ...
# 16135  This study was aimed at improving the academic...
# 16136  This study has tried to find the gap of health...
# 16137  The purpose of this study is to analyse the pr...
# 16138  본 연구는 거절민감성과 사회불안에 대한 개입으로 마음챙김의 가능성에 주목했다. 거절...
# 16139  의료의 전문적 특성으로 인해 의사들에게는 고유의 직업 윤리가 요구되며, 임상 현장에...
#
# [16140 rows x 7 columns]

# %%
_2 = pd.read_excel('./2_우울.xlsx')
_2
# Out:
#                                                   title  \
# 0     여성 우울증 환자에서 Aripiprazole과 Bupropion 부가요법의 우울증상...
# 1                  우울장애 환자의 자살사고에 우울, 낙관성과 감사성향이 미치는 영향
# 2     한국형 우울장애 약물치료 알고리듬 2017(Ⅵ) : 안정성, 부작용, 동반 신체질환...
# 3                                      청소년에서 집단따돌림과 우울증
# 4                       지역사회에서 주산기 우울감을 호소하는 산모의 치료 연계율
# ...                                                 ...
# 7627       ICT를 활용한 독거노인 헬스케어서비스 실증 연구 - 송파구 지역을 중심으로 -
# 7628                교양체육 수업형태에 따른 대학생들의 체력, 신체조성 및 정신건강
# 7629              한국어판 개정된 아동발현불안척도 2판의 심리측정적 속성에 대한 연구
# 7630                     제천 화재 사고 피해자들의 정신병리에 대한 후향적 분석
# 7631       알츠하이머병 및 경도인지장애 환자에서 갑상선 관련 호르몬과 인지기능과의 상관관계
#
#                                                  author  \
# 0     금무성\r\n\t\t\t\t\t\t\t\r\n                     ...
# 1     황지현\r\n\t\t\t\t\t\t\t\r\n                     ...
# 2     이정구\r\n\t\t\t\t\t\t\t\r\n                     ...
# 3     홍현미\r\n\t\t\t\t\t\t\t\r\n                     ...
# 4     노승훈\r\n\t\t\t\t\t\t\t\r\n                     ...
# ...                                                 ...
# 7627  이지연 ( Lee Ji Yeon )\r\n\t\t\t\t\t\t\t\r\n     ...
# 7628  김명수(Myoung-Soo Kim)\r\n\t\t\t\t\t\t\t\r\n     ...
# 7629  차윤지(Yun Ji Cha)\r\n\t\t\t\t\t\t\t\r\n         ...
# 7630  전선영\r\n\t\t\t\t\t\t\t\r\n                     ...
# 7631  박다윤\r\n\t\t\t\t\t\t\t\r\n                     ...
#
#                                                   book  year  \
# 0                              우울조울병(Mood and Emotion)  2018
# 1                              우울조울병(Mood and Emotion)  2017
# 2                              우울조울병(Mood and Emotion)  2017
# 3                              우울조울병(Mood and Emotion)  2018
# 4                              우울조울병(Mood and Emotion)  2017
# ...                                                ...   ...
# 7627                                          디자인융복합연구  2017
# 7628                                   한국엔터테인먼트산업학회논문지  2013
# 7629             Korean Journal of Clinical Psychology  2020
# 7630                                       Crisisonomy  2019
# 7631  정신신체의학(Korean Journal of Psychosomatic Medicine)  2019
#
#                                                 keyword  \
# 0     아리피프라졸\r\n\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\r...
# 1     essive disorder\r\n\t\t\t\t\t\t\t\t\r\n\t\t\t\...
# 2     주요우울장애\r\n\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\r...
# 3     Bullying\r\n\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t...
# 4     Postpartum depression\r\n\t\t\t\t\t\t\t\t\r\n\...
# ...                                                 ...
# 7627  Healthcare\r\n\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t...
# 7628  Physical Fitness\r\n\t\t\t\t\t\t\t\t\r\n\t\t\t...
# 7629  manifest anxiety\r\n\t\t\t\t\t\t\t\t\r\n\t\t\t...
# 7630  psychopathology\r\n\t\t\t\t\t\t\t\t\r\n\t\t\t\...
# 7631  Thyroid hormones\r\n\t\t\t\t\t\t\t\t\r\n\t\t\t...
#
#                                            abstract_kor  \
# 0     Objectives : The purpose of this study was to ...
# 1     Objective : To present effects of depression, ...
# 2     Objectives : This study was undertaken to revi...
# 3     Depression is one of the most prevalent mental...
# 4     Objectives : This study investigated the refer...
# ...                                                 ...
# 7627  고령화 사회가 가속화되면서 2016년 기준 독거노인 100만 시대가 도래했다. 독거...
# 7628  본 연구의 목적은 기존의 일반적인 체육교양 수업을 탈피하여 개인의 체력을 기준으로 ...
# 7629  개정된 아동발현불안척도(The Revised Children’s Manifest A...
# 7630  This study was conducted retrospectively to id...
# 7631  Objectives：The association between thyroid-rel...
#
#                                            abstract_eng
# 0     1 이중서, "한국판 Hamilton 우울증 평가 척도의 신뢰도, 타당도 연구" 대...
# 1     1 권선중, "한국판 감사 성향 척도(K-GQ-6)의신뢰도 및 타당도" 한국건강심리...
# 2     1 서정석, "한국형 우울장애 약물치료 알고리듬 2006 (Ⅰ)" 대한신경정신의학회...
# 3     1 이승연, "초등학교 학교폭력 가해, 피해, 가해-피해 집단의 심리사회적 특성" ...
# 4     1 한귀원, "한국어판 에딘버러 산후우울 척도 : 신뢰도와 타당도" 대한생물치료정신...
# ...                                                 ...
# 7627  With the acceleration of aging, one million so...
# 7628  The objective of this study is to suggest a de...
# 7629  The purpose of the study was to examine the ps...
# 7630  본 연구는 제천 화재 사고 후 심리지원단에 의뢰된 대상자들의 재난에서의 반응 및 증...
# 7631  연구목적: 갑상선관련 호르몬과 인지기능의 상관 유무는 논란이 되고 있다. 알츠하이머...
#
# [7632 rows x 7 columns]

# %%
_3_1 = pd.read_excel('./3_1_China.xlsx')
_3_1
# Out:
#                                                    title  \
# 0      Exploring China`s Conduct of Foreign Relations...
# 1      Exploring China`s Conduct of Foreign Relations...
# 2      중국이 바라는 세계는 곧 ‘천하’일까?: Catherine Jones, China’...
# 3      직접경험, 관계적 통로, 텍스트적 통로가 중국 국가이미지 형성에 미치는 영향에 대한...
# 4                          중국의 ‘일대일로’ 구상에 대한 세 가지 관점의 제안
# ...                                                  ...
# 13305                                高麗ㆍ後周 관계와 光宗의 영토 확장
# 13306                                   中韩比较视域下的“油”的演变研究
# 13307                               감염병이 항공사 서비스에 미치는 영향
# 13308       『西京稗史抄畧』과 ｢平壤戰(爭及其前後ノ)記｣-淸日戰爭 관련 기록과 漢文의 위치-
# 13309                                     琉球의 왕권과 그의 상징물
#
#                                                   author  \
# 0                                          ( Fu Zuo Wu )
# 1                                   ( Renato De Castro )
# 2                                                    조의행
# 3                                                    김인숙
# 4                                                    김진영
# ...                                                  ...
# 13305                                                허인욱
# 13306                                                박덕영
# 13307  오철\r\n\t\t\t\t\t\t\t\r\n                      ...
# 13308                                                송호빈
# 13309                                                양수지
#
#                                                   book  year  \
# 0                                    ASIAN PERSPECTIVE  2015
# 1                                    ASIAN PERSPECTIVE  2015
# 2                                               현상과 인식  2019
# 3                             Journal of China Studies  2018
# 4                             Journal of China Studies  2019
# ...                                                ...   ...
# 13305                                             전북사학  2013
# 13306  중국언어연구(Journal of Chinese Linguistics in Korea)  2019
# 13307                                        한국항공경영학회지  2020
# 13308                                          韓國漢文學硏究  2019
# 13309   동북아 문화연구(Journal of North-east Asian cultures)  2010
#
#                                                  keyword  \
# 0      China`s energy diplomacy\r\n\t\t\t\t\t\t\t\t\r...
# 1      South China Sea dispute\r\n\t\t\t\t\t\t\t\t\r\...
# 2      국제규범\r\n\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\r\n...
# 3      National Image of China\r\n\t\t\t\t\t\t\t\t\r\...
# 4      the Belt and Road Initiative\r\n\t\t\t\t\t\t\t...
# ...                                                  ...
# 13305  고려\r\n\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\r\n\t...
# 13306  Chinese monosyllabic vocabulary\r\n\t\t\t\t\t\...
# 13307  감염병\r\n\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\r\n\...
# 13308  The Sino-Japanese War(淸日戰爭)\r\n\t\t\t\t\t\t\t\...
# 13309  tribute-installation system\r\n\t\t\t\t\t\t\t\...
#
#                                             abstract_kor  \
# 0      China, the world`s largest energy consumer, ha...
# 1      Using the Scarborough Shoal standoff between C...
# 2      This article attempts to review Catherine Jone...
# 3      This study investigated the effects of direct ...
# 4      This paper intends to suggest three perspectiv...
# ...                                                  ...
# 13305  The relationship between Goryo and Later Chou(...
# 13306  The study of Chinese monosyllabic vocabulary a...
# 13307  The purpose of this study was to find the serv...
# 13308  Compared to the importance of the Sino-Japanes...
# 13309  This paper focuses on the sovereign power of L...
#
#                                             abstract_eng
# 0      1 IEA (International Energy Agency), "World En...
# 1      1 Russett, Bruce, "World Politics: The Menu of...
# 2      국제규범, 자유적 국제질서, 중국의 규범적 권력, 주이 글은 캐서린 존스의 Chin...
# 3      1 신호창, "해외홍보 및 광고전략 수립을 위한 ‘95~’97 미국언론에 나타난 국...
# 4      1 이정미, "파키스탄-중국 경제회랑 사업 추진 현황과 과제" 대외경제정책연구원 2...
# ...                                                  ...
# 13305  Ⅰ. 머리말\r\r\n\t\t\t\t\t\r\n\t\t\t\t\t Ⅱ. 高麗·後周 ...
# 13306  汉语单音节词汇及其语义演变过程的研究，是一个重要的学术领域.论其研究方法创新,可在一般性的考...
# 13307  본 연구는 감염병의 확산에 따라 소비자들이 지각하는 위험을 고려하여 항공사들이 제공...
# 13308  淸日戰爭(中日甲午戰爭ㆍ日淸戰爭ㆍ第1次中日戰爭ㆍ第1次朝鮮戰爭)의 중요성에 비해, 청일...
# 13309  I. 머리말\r\r\n\t\t\t\t\t\r\n\t\t\t\t\t II. 琉球의 왕...
#
# [13310 rows x 7 columns]

# %%
_3_2 = pd.read_excel('./3_2_China.xlsx')
_3_2
# Out:
#                                                    title  \
# 0                                      WTO 체제에서의 서비스 원산지
# 1               동(東)아시아의 법규범(法規範) 전파의 실태와 출토문자자료(出土文字資料)
# 2                      중국적 사유방식의 특징을 바탕으로 한 위챗 디자인 사례 연구
# 3      제3국 출생 북한이탈주민 자녀(아동청소년)의 삶의 제한성으로부터 가능성 연계과정에 ...
# 4                           메니에르 병의 침 치료에 관한 최근 임상 연구 동향
# ...                                                  ...
# 13726  독일과 한국의 노년영화 비교 연구 - <아무르>(2012)와 <님아, 그 강을 건너...
# 13727                                영아교사의 교육신념과 영아-교사관계
# 13728                                          길재와 나와 북한
# 13729  방송통신사업자의 부당한 이용자 차별 행위의 위법성 판단 기준의 타당성 및 효과적 규...
# 13730  들깻잎 중 chlorantraniliprole과 tetraconazole 잔류양상의...
#
#                                                   author  \
# 0                                         허난이(Hur, Nany)
# 1                              三上喜孝 ( Mikami Yoshitaka )
# 2      리신\r\n\t\t\t\t\t\t\t\r\n                      ...
# 3                                  김현경(Kim, Hyun Kyoung)
# 4      이규영\r\n\t\t\t\t\t\t\t\r\n                     ...
# ...                                                  ...
# 13726                              허남영 ( Heo Nam-young )
# 13727                                                유주연
# 13728                                  이대근(Yi, Dae-keun)
# 13729  이영주 ( Yeong-ju Lee )\r\n\t\t\t\t\t\t\t\r\n    ...
# 13730  김효정(Hyo-Jeong Kim)\r\n\t\t\t\t\t\t\t\r\n      ...
#
#                                                     book  year  \
# 0                                                국제경제법연구  2014
# 1                    大東文化硏究(Journal of Eastern studies )  2017
# 2                                          커뮤니케이션 디자인학연구  2017
# 3                                                 젠더와 문화  2015
# 4      한방안이비인후피부과학회지(The Journal of Korean Oriental O...  2018
# ...                                                  ...   ...
# 13726  독일언어문학(Zeitschrift fur Deutsche Sprache und Li...  2018
# 13727                                           한국교원교육연구  2017
# 13728                                             현대북한연구  2020
# 13729  인터넷정보학회논문지(Journal of Internet Computing and S...  2012
# 13730                                             농약과학회지  2019
#
#                                                  keyword  \
# 0      서비스 원산지\r\n\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\...
# 1      동아시아문화권\r\n\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\...
# 2      The way of Chinese thinking\r\n\t\t\t\t\t\t\t\...
# 3      제3국 출생 북한이탈주민자녀\r\n\t\t\t\t\t\t\t\t\r\n\t\t\t\...
# 4      Meniere's disease\r\n\t\t\t\t\t\t\t\t\r\n\t\t\...
# ...                                                  ...
# 13726  노년영화\r\n\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\r\n...
# 13727  영아\r\n\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\r\n\t...
# 13728  류길재\r\n\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\r\n\...
# 13729  offering of promotional gifts\r\n\t\t\t\t\t\t\...
# 13730  Biological half-life\r\n\t\t\t\t\t\t\t\t\r\n\t...
#
#                                             abstract_kor  \
# 0      불확정적인 개념의 ‘서비스’가 무역의 대상이 되는 경우 어느 국가로부터 공급되는지,...
# 1      본 논문의 목적은 동아시아문화권에서 법규범이 구체적으로 어떻게 전파해 나갔는지를 살...
# 2      정보화시대에 들어선 후에 정보유동속도가 점점 빨라지면서 여러 국가와 지역 간의 문화...
# 3      본 연구의 목적은 제3국 출생 북한이탈주민자녀를 양육한 북한출신 어머니가 인식한 중...
# 4      Objectives : The purpose of this study is to i...
# ...                                                  ...
# 13726  ‘노년’은 독일과 한국의 노년영화에서 ‘늙음, 죽음 인식’, ‘사랑과 성’, ‘세대...
# 13727  본 연구는 교사의 교육신념과 교사가 인식하는 영아-교사관계의 양상을 살펴보고, 교사...
# 13728  비교적 보수적인 류길재 북한대학원대학교 교수와 나는 북한 문제 인식에서 차이가 있었...
# 13729  본 연구는 방송·통신 서비스의 경품 및 요금 감면 행위의 위법성 판단 기준과 규제 ...
# 13730  들깻잎에 살충제 chlorantraniliprole과 살균제 tetraconazol...
#
#                                             abstract_eng
# 0      In the WTO regime, there is a lack of the prec...
# 1      The purpose of this thesis is to make it clear...
# 2      Stepping into information age, as information ...
# 3      The purpose of this study is to provide an ori...
# 4      1 이미숙, "청심연자탕으로 호전된 메니에르병 환자 치험 1례" 사상체질의학회 26...
# ...                                                  ...
# 13726  Die Filme zum Alter und zum Altern in Korea un...
# 13727  The purpose of this study was to examine aspec...
# 13728  The late Ryoo Kihl-jae, a moderate conservativ...
# 13729  This study aims to find out the effectiveness ...
# 13730  Chlorantraniliprole and tebuconazole were diff...
#
# [13731 rows x 7 columns]

# %%
_4 = pd.read_excel('./4_Depression.xlsx')
_4
# Out:
#                                                   title  \
# 0     Depression and Quality of Life among Postmenop...
# 1     Prevalence of and factors associated with anxi...
# 2     한국판 남성우울척도(Korean Masculine Depression Scale) ...
# 3     A Study on the Relationship between Depression...
# 4     Effect of Phytoestrogen on Depression and Anxi...
# ...                                                 ...
# 8902           (신)실버소외계층을 위한 스마트 콘텐츠 UX 프레임워크 서비스디자인 연구
# 8903                               노천명시에 나타나는 고독의 변모 양상
# 8904                         박선석과 이문구 소설에서의 상처 치유 양상 비교
# 8905  기획논문 : 식민성과 제국의 네트워크, 정념의 공동체 ; 정체(停滯),(政體) 감각...
# 8906             연결잠금장치를 활용한 연속성 디자인의 시스템 주얼리 디자인 연구 개발
#
#                                                  author  \
# 0     ( Mamun Ibn Bashar )\r\n\t\t\t\t\t\t\t\r\n    ...
# 1     ( Junghwa Chung )\r\n\t\t\t\t\t\t\t\r\n       ...
# 2     우성범\r\n\t\t\t\t\t\t\t\r\n                     ...
# 3     ( Heeseon Jang )\r\n\t\t\t\t\t\t\t\r\n        ...
# 4                                   ( Abolfazl Fattah )
# ...                                                 ...
# 8902                                 이재익 ( Lee Jae Lk )
# 8903                                                권영옥
# 8904                            김현철 ( Hyeon Cheol Kim )
# 8905                              신지영 ( Ji Young Shin )
# 8906  최이란(Choi, Lee Ran)\r\n\t\t\t\t\t\t\t\r\n      ...
#
#                                                    book  year  \
# 0               대한폐경학회지(Journal of Menopausal Medicine)  2017
# 1               The Korean Journal of Internal Medicine  2018
# 2       人間發達硏究(The Korean Journal of Human Development)  2014
# 3     한국보건정보통계학회지(Journal of The Korea Socity of Hea...  2017
# 4               대한폐경학회지(Journal of Menopausal Medicine)  2017
# ...                                                 ...   ...
# 8902    한국과학예술융합학회(The Korean Society of Science & Art)  2016
# 8903             여성문학연구(Feminism and Korean literature)  2011
# 8904                                           현대문학의 연구  2016
# 8905  石堂論叢(JOURNAL OF SOKDANG ACADEMIC RESEARCH OF T...  2012
# 8906    한국과학예술융합학회(The Korean Society of Science & Art)  2018
#
#                                                 keyword  \
# 0     Bangladesh\r\n\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t...
# 1     Anxiety\r\n\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\...
# 2     male depression\r\n\t\t\t\t\t\t\t\t\r\n\t\t\t\...
# 3     Depression\r\n\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t...
# 4     Anxiety\r\n\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\...
# ...                                                 ...
# 8902  Senior Generation(시니어세대)\r\n\t\t\t\t\t\t\t\t\r...
# 8903  loneliness\r\n\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t...
# 8904  박선석\r\n\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\r\n\...
# 8905  제국 일본\r\n\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\r\...
# 8906  Locking Device(연결 잠금장치)\r\n\t\t\t\t\t\t\t\t\r\...
#
#                                            abstract_kor  \
# 0     Objectives: The aims of the research are to ex...
# 1     Background/Aims: The purpose of the present st...
# 2     This study sought to validate the Masculine De...
# 3     목적: 이 연구는 경기 북부 대학생을 대상으로 우울 정도와 이상섭식과의 관계를 규명...
# 4     Objectives: In this systematic review, the eff...
# ...                                                 ...
# 8902  최근, 다양한 문화 콘텐츠의 확보로 스마트 디바이 스와의 쉬운 접근을 통해 참여와 ...
# 8903  이 논문은 노천명이 섬세하고 절제된 일상적인 삶과는 달리, 구원으로서의작가의식과 명...
# 8904  중국조선족문학과 한국문학은 비슷한 문화적 전통과 역사적 연원을 갖고 있다. 같은 민...
# 8905  본 논문에서는 제국 일본의 일본어화 정책이 본격적으로 진행되었던 1937년부터 19...
# 8906  주얼리는 신체 착용을 위한 제품으로 장식적 표현수단과 인간의 미적 가치를 표출하고자...
#
#                                            abstract_eng
# 0     1 Dennerstein L, "Well-being, symptoms and the...
# 1     1 Yoo SW, "Validity of Korean version of the m...
# 2     본 연구는 한국사회의 남성우울을 측정하기 위한 측정도구를 마련하기 위해 진행되었다....
# 3     Objectives: This study was conducted to identi...
# 4     1 Ghazanfarpour M, "The relationship between w...
# ...                                                 ...
# 8902  Recently, diverse cultural contents enabled ea...
# 8903  In this study on the poetess of Roh Cheonmyeon...
# 8904  Chinese Korean literature and Korean literatur...
# 8905  This paper deals with multi-racial round-table...
# 8906  Jewelry is product to be worn on the body, and...
#
# [8907 rows x 7 columns]

# %%
_5 = pd.read_excel('./5_자기효능감.xlsx')
_5
# Out:
#                                                   title  \
# 0     수퍼바이지가 지각한 작업동맹이 상담자활동 자기효능감과 수퍼비전 만족도에 미치는 영향...
# 1     내현적 자기애가 사회불안에 미치는 영향\r\n\t\t\t \t\r\n\t\t\t \...
# 2                        중학생의 시험불안, 학업적 자기효능감, 학업성취의 관계
# 3                    대학생의 애착, 자기효능감, 학습몰입이 학업성취에 미치는 영향
# 4                        대학생의 학업적 자기효능감이 학교생활적응에 미치는 영향
# ...                                                 ...
# 5543                         한국형 도형심리 양육태도 척도 개발 타당성 연구
# 5544           세계체계 분석의 형성과 발전 : 월러스틴의 지적 여정과 비판에 대한 고찰
# 5545  Computational Thinking 증진을 위한 학습자 중심의 교수학습 전략의 효과
# 5546                장애인거주시설 생활지도원의 조직신뢰 영향요인에 관한 탐색적 연구
# 5547            중학생의 진로성숙도에 영향을 미치는 요인: 창업·경제프로그램을 중심으로
#
#                                                  author  \
# 0     주영아\r\n\t\t\t\t\t\t\t\r\n                     ...
# 1     최인선 ( In Son Choi )\r\n\t\t\t\t\t\t\t\r\n     ...
# 2     전현정(Hyeon Jeong Jeon)\r\n\t\t\t\t\t\t\t\r\n   ...
# 3     오층광(Chung Kwang Oh)\r\n\t\t\t\t\t\t\t\r\n     ...
# 4     군재환(Jae Hwan Kwon)\r\n\t\t\t\t\t\t\t\r\n      ...
# ...                                                 ...
# 5543  김수자 ( Soo Ja Kim )\r\n\t\t\t\t\t\t\t\r\n      ...
# 5544                                  이광근(Kwangkun Lee)
# 5545                                                김수환
# 5546                                                 이웅
# 5547                                안윤숙 ( An Yun Sook )
#
#                                                    book  year  \
# 0                                               청소년상담연구  2014
# 1                    상담학연구(Korea Journal of Counseling)  2013
# 2               청소년학연구(Korean journal of youth studies)  2015
# 3               청소년학연구(Korean journal of youth studies)  2015
# 4                                              청소년 문화포럼  2013
# ...                                                 ...   ...
# 5543  인문사회 21(The Journal of Humanities and Social s...  2015
# 5544                                             현상과 인식  2020
# 5545  정보교육학회논문지(JOURNAL OF The Korean Association of...  2015
# 5546                                            장애인복지연구  2020
# 5547  인문사회 21(The Journal of Humanities and Social s...  2017
#
#                                                 keyword  \
# 0     작업동맹\r\n\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\r\n...
# 1     내현적 자기애\r\n\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\...
# 2     시험불안\r\n\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\r\n...
# 3     애착\r\n\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\r\n\t...
# 4     대학생\r\n\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\r\n\...
# ...                                                 ...
# 5543  한국형 도형심리유형\r\n\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t...
# 5544  월러스틴\r\n\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\r\n...
# 5545  SW 교육\r\n\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\r\...
# 5546  조직신뢰\r\n\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\r\n...
# 5547  진로성숙도(Career Maturity)\r\n\t\t\t\t\t\t\t\t\r\n...
#
#                                            abstract_kor  \
# 0     본 연구는 수퍼바이지가 지각한 작업동맹이 상담자활동 자기효능감과 수퍼비전 만족도에 ...
# 1     본 연구는 내현적 자기애가 사회불안에 미치는 영향에서 내면화된 수치심, 사회적 자기...
# 2     본 연구의 목적은 시험불안, 학업적 자기효능감, 학업성취의 시간경과에 따른 변인간의...
# 3     본 연구는 자기효능감 모델을 적용하여 대학생들의 부모애착과 학업성취의 관계에서 자기...
# 4     본 연구의 목적은 대학생의 학업적 자기효능감과 자기조절학습능력 및 학교생활적응과의 ...
# ...                                                 ...
# 5543  본 연구는 한국형 도형심리 양육태도 척도 개발을 위한 타당도를 검증하는 데 있다. ...
# 5544  세계체계 분석은 1970년대 초 월러스틴에 의해서 세상에 등장하였지만, 이후에는 집...
# 5545  본 연구의 목적은 SW 교육의 목표인 Computational Thinking(CT...
# 5546  The purpose of this study is to explore the fa...
# 5547  본 연구는 중학생의 진로성숙도에 영향을 미치는 요인을 알아보고자 양적 연구방법으로 ...
#
#                                            abstract_eng
# 0     The present study aimed at identifying the med...
# 1     The purpose of this study is to set up a causa...
# 2     The purpose of this paper was to analyze longi...
# 3     The purpose of this study was to investigate t...
# 4     The purpose of this study was to investigate r...
# ...                                                 ...
# 5543  The purpose of this study was to test validity...
# 5544  This study aims to reconstruct both Immanuel W...
# 5545  The purpose of this study is to verify the eff...
# 5546  본 연구는 생활지도원의 조직신뢰 영향요인을 중증 및 장애영유아거주시설과 장애유형별거...
# 5547  This study was conducted as quantitative resea...
#
# [5548 rows x 7 columns]

# %%
_6 = pd.read_excel('./6_인공지능.xlsx')
_6
# Out:
#                                                   title  \
# 0                                 인공지능 기술분석을 위한 베이지안 추론
# 1     텍스트 마이닝 기법을 활용한 인공지능 기술개발 동향 분석 연구: 깃허브 상의 오픈 ...
# 2                           딥러닝의 변수 중요도를 이용한 인공지능 기술 분석
# 3     인공지능 기술 기반 인슈어테크와 디지털보험플랫폼 성공사례 분석: 중국 평안보험그룹을...
# 4                              심볼릭 인공지능을 위한 R 심볼릭 데이터분석
# ...                                                 ...
# 2865                ICT 융복합 시설설치의 원스톱 행정체제 도입에 관한 법적 검토
# 2866          한국형사법학 60년의 회고와 전망 -형법각론분야: 개인적 법익에 대한 죄-
# 2867                       비교법적, 행동주의적 관점에서 본 민사소송의 증명도
# 2868            허위조작정보(소위 ‘가짜뉴스’) 규제에 대한 헌법적 문제점에 관한 연구
# 2869                               포스트휴먼 시대의 로봇과 인간의 윤리
#
#                                                  author  \
# 0     최준혁(Junhyeog Choi)\r\n\t\t\t\t\t\t\t\r\n      ...
# 1     정지선\r\n\t\t\t\t\t\t\t\r\n                     ...
# 2     김승환(Seungwhan Kim)\r\n\t\t\t\t\t\t\t\r\n      ...
# 3     이재원\r\n\t\t\t\t\t\t\t\r\n                     ...
# 4                                      전성해(Sunghae Jun)
# ...                                                 ...
# 2865                                                김남욱
# 2866                                                강동범
# 2867                                                박혜진
# 2868                                                지성우
# 2869  유은순(Eun-Soon You)\r\n\t\t\t\t\t\t\t\r\n       ...
#
#                                                    book  year  \
# 0     한국지능시스템학회논문지(Journal of Korean institute of in...  2018
# 1                                                지능정보연구  2019
# 2     한국지능시스템학회논문지(Journal of Korean institute of in...  2019
# 3                                                지능정보연구  2020
# 4     한국지능시스템학회논문지(Journal of Korean institute of in...  2017
# ...                                                 ...   ...
# 2865                           법학논총(Dankook Law Review)  2016
# 2866                                              刑事法硏究  2017
# 2867        人權과 正義 : 大韓辯護士協會誌(Human rights and justice)  2020
# 2868                                   公法硏究(Public Law)  2019
# 2869                                         한국콘텐츠학회논문지  2018
#
#                                                 keyword  \
# 0     인공지능\r\n\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\r\n...
# 1     Artificial Intelligence\r\n\t\t\t\t\t\t\t\t\r\...
# 2     딥러닝\r\n\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\r\n\...
# 3     Artificial Intelligence Technology\r\n\t\t\t\t...
# 4     심볼릭 인공지능\r\n\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t...
# ...                                                 ...
# 2865  민원1회 방문제\r\n\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t...
# 2866  individual benefit and protection of the law\r...
# 2867  standard of proof\r\n\t\t\t\t\t\t\t\t\r\n\t\t\...
# 2868  표현의 자유\r\n\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\r...
# 2869  로봇윤리\r\n\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\r\n...
#
#                                            abstract_kor  \
# 0     인간과 같은 지능을 갖는 컴퓨터를 만드는 인공지능 기술에 대한 눈부신 발전에 의해 ...
# 1     Artificial intelligence (AI) is one of the mai...
# 2     인공지능 기술은 빠른 속도로 발전하고 있다. 특히 인공지능 개발을 이끌고 있는 많은...
# 3     Recently, the global insurance industry is rap...
# 4     컴퓨터와 인간은 분명 다르지만 기본적으로 데이터를 저장하고 처리하는 개념적 측면에서...
# ...                                                 ...
# 2865  The development of fusion technology of scienc...
# 2866  The Korean Criminal Law Association was founde...
# 2867  There is one striking difference between civil...
# 2868  ‘Freedom of Speech,’ constitutionally is a not...
# 2869  로봇의 영역이 인간의 정신적, 감정적 노동까지 대신하는 지능형 로봇으로 진화하면서 ...
#
#                                            abstract_eng
# 0     Due to the remarkable development of artificia...
# 1     제4차 산업혁명을 이끄는 주요 원동력 중 하나인 인공지능 기술은 이미지와 음성 인식...
# 2     Artificial intelligence (AI) technology has be...
# 3     최근 전 세계 보험업계에도 기계학습, 자연어 처리, 딥러닝 등의 인공지능 기술 활용...
# 4     Computers and humans are different, but basica...
# ...                                                 ...
# 2865  과학기술과 ICT융합기술의 발전은 편안하고 안전한 유비쿼터스도시 기반시설의 조성을 ...
# 2866  60년 전인 1957년 6․25전쟁의 상처가 아물지 않은 어려운 여건 하에서 훌륭한...
# 2867  시민법(civil law)과 보통법(common law) 사이에 민사소송에서의 증명...
# 2868  헌법상 ‘표현의 자유’라 함은 헌법 제21조의 ‘언론･출판의 자유’와 ‘집회･결사의...
# 2869  As the field of robots is evolving to intellig...
#
# [2870 rows x 7 columns]

# %%
_7 = pd.read_excel('./7_청소년.xlsx')
_7
# Out:
#                                                    title  \
# 0      초기 청소년기의 변화에 대한 부모-자녀의 인식에  관한 연구\r\n\t\t\t \t...
# 1      청소년 시설 이용실태 및 개선방안에 대한 연구\r\n\t\t\t \t\r\n\t\t...
# 2      학교중단 청소년의 ‘나의 삶 찾기’ 과정\r\n\t\t\t \t\r\n\t\t\t ...
# 3      청소년시설의 가상화에 관한 연구\r\n\t\t\t \t\r\n\t\t\t \t\r\...
# 4      청소년의 영적 성숙도와 종교 성향이 심리적 안녕감에 미치는 영향\r\n\t\t\t ...
# ...                                                  ...
# 15397                         문화적 양극화 해소를 위한 기부문화 활성화 정책
# 15398  중국 특색의 ‘권위주의적 조합주의형’ 정부-민간 정책협력–기금회의 성장과 발전을 중...
# 15399                소아 기관지 천식 환자의 비염 발병 예측에서 호기산화질소의 역할
# 15400    학교수업 및 자기학습과 대비한 사교육의 수학성적 향상 효과성 인식에 대한 종단적 고찰
# 15401                지역아동센터를 이용하는 초등학생의 학업성취에 영향을 미치는 요인
#
#                                                   author  \
# 0      소수연\r\n\t\t\t\t\t\t\t\r\n                     ...
# 1      윤준선\r\n\t\t\t\t\t\t\t\r\n                     ...
# 2      이미원\r\n\t\t\t\t\t\t\t\r\n                     ...
# 3      황성재\r\n\t\t\t\t\t\t\t\r\n                     ...
# 4      김미경\r\n\t\t\t\t\t\t\t\r\n                     ...
# ...                                                  ...
# 15397                                                황창순
# 15398  장숙인\r\n\t\t\t\t\t\t\t\r\n                     ...
# 15399  고한석\r\n\t\t\t\t\t\t\t\r\n                     ...
# 15400                                                김경년
# 15401  차윤님\r\n\t\t\t\t\t\t\t\r\n                     ...
#
#                                                  book  year  \
# 0                                             청소년상담연구  2014
# 1                                             청소년시설환경  2010
# 2                                             청소년상담연구  2013
# 3                                             청소년시설환경  2014
# 4                                             청소년상담연구  2014
# ...                                               ...   ...
# 15397                                          문화정책논총  2010
# 15398   국제지역연구(Journal of International Area Studies)  2017
# 15399            Allergy Asthma & Respiratory Disease  2012
# 15400  敎育學硏究(Korean journal of educational research )  2010
# 15401                                          학교사회복지  2016
#
#                                                  keyword  \
# 0      초기 청소년기\r\n\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\...
# 1      청소년 시설\r\n\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\r...
# 2      학교중단\r\n\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\r\n...
# 3      virtual\r\n\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\...
# 4      청소년\r\n\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\r\n\...
# ...                                                  ...
# 15397  Giving\r\n\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\r...
# 15398  Chinese foundations\r\n\t\t\t\t\t\t\t\t\r\n\t\...
# 15399  Asthma\r\n\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\r...
# 15400  learning method\r\n\t\t\t\t\t\t\t\t\r\n\t\t\t\...
# 15401  학업성취\r\n\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\r\n...
#
#                                             abstract_kor  \
# 0      This study aimed to obtain basic data to find ...
# 1      요약 : 자라나는 청소년들에게는 학교교육 외에도 여가활동과 취미개발. 건전한 문화 ...
# 2      The purpose of this study is to understand the...
# 3      Abstract\r\n\t\t\t\t\t\r\n\t\t\t\t\t I. 서론\r\n...
# 4      The purpose of this study is to examine the ef...
# ...                                                  ...
# 15397  This study aims to suggest activation policies...
# 15398  Since early 1980s, Chinese government induced ...
# 15399  Purpose : Fractional exhaled nitric oxide (FeN...
# 15400  The purpose of this study was to investigate t...
# 15401  This study intended to understand the factors ...
#
#                                             abstract_eng
# 0      본 연구의 목적은 초기 청소년기의 청소년과 부모를 대상으로 이들이 경험하고 있는 초...
# 1      요약\r\n\t\t\t\t\t\r\n\t\t\t\t\tⅠ. 서론\r\n\t\t\t\...
# 2      본 연구는 학교중단 청소년들의 학교중단 과정과 그 이후의 삶을 통한 ‘나의 삶 찾기...
# 3      1 박옥식, "한국 청소년 수련시설 운영의 문제점과개선방안" 134-, 2009\r...
# 4      본 연구는 청소년의 영적 성숙도와 종교 성향이 심리적 안녕감에 어떠한 영향을 미치는...
# ...                                                  ...
# 15397  본 논문은 기부에 관한 다양한 관심 가운데 일반적인 기부 활성화 방안을 제시하면서 ...
# 15398  중국은 1980년대 이후 사회공공영역에서 활동하는 민간단체들이 급속하게 늘어났고, ...
# 15399  목 적:호기산화질소(exhaled nitric oxide, FeNO)의농도는 비침습...
# 15400  본 연구에서는 한국청소년패널조사 1차～5차 자료를 활용하여 수학과목에 대한 중학생들...
# 15401  본 연구는 보건복지부와 지역아동센터중앙지원단의 연구위탁을 받은 한국청소년정책연구원에...
#
# [15402 rows x 7 columns]

# %%
_8_1 = pd.read_excel('./8_1_Satisfaction.xlsx')
_8_1
# Out:
#                                                    title  \
# 0      온라인과 오프라인 간 만족전이(Satisfaction Transfer)를 통한 은행...
# 1      아파트 주거만족도 평가 모형의 개발과 적용: KARSI(Korea Apartment...
# 2      LCSI(Library Customer Satisfaction Index) Lite...
# 3      한국과 중국 인터넷 쇼핑몰에서의 e-Satisfaction 결정요인과 결과요인에 대...
# 4      The association of physicians` caring attitude...
# ...                                                  ...
# 16214       수단-목적사슬모델을 적용한 레스토랑 혼밥족이 지각하는 서비스스케이프에 대한 연구
# 16215               < 일반논문 > : 군 초급간부의 직무행태와 조직성과에 관한 연구
# 16216                     경사주거지의 경관 개선을 위한 형태기반의 설계지침 구상
# 16217       돌봄서비스 이용자의 서비스오남용과 서비스 제공자의 직무태도와의 관계에 관한 연구
# 16218                    중고령자 재취업의 결정요인, 일자리 만족도 및 고용안정성
#
#                                                   author  \
# 0      현용호\r\n\t\t\t\t\t\t\t\r\n                     ...
# 1      이유재 ( You Jae Yi )\r\n\t\t\t\t\t\t\t\r\n      ...
# 2                                      오동근(Dong-Geun Oh)
# 3      윤남수 ( Nam Soo Yoon )\r\n\t\t\t\t\t\t\t\r\n    ...
# 4      ( Chanhyun Park )\r\n\t\t\t\t\t\t\t\r\n       ...
# ...                                                  ...
# 16214  이은진\r\n\t\t\t\t\t\t\t\r\n                     ...
# 16215  장준보 ( Junbo Chang )\r\n\t\t\t\t\t\t\t\r\n     ...
# 16216  손창희(Son, Chang-Hee)\r\n\t\t\t\t\t\t\t\r\n     ...
# 16217                                  최소연(Choi, So Yun)
# 16218                                                강순희
#
#                                                     book  year  \
# 0                                                 기업경영연구  2012
# 1                                                 소비자학연구  2016
# 2      한국문헌정보학회지(Journal of the Korean Library and In...  2013
# 3      고객만족경영연구(Academy of customer satisfaction mana...  2011
# 4         병원경영학회지(Korean journal of hospital management)  2015
# ...                                                  ...   ...
# 16214  한국조리학회지(Culinary science and hospitality resea...  2019
# 16215                                             국정관리연구  2015
# 16216                                   대한건축학회 논문집 : 계획계  2013
# 16217            한국지역사회복지학(Journal of community welfare)  2013
# 16218                                             취업진로연구  2016
#
#                                                  keyword  \
# 0      Bank Service Quality\r\n\t\t\t\t\t\t\t\t\r\n\t...
# 1      주거만족도\r\n\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\r\...
# 2      공공도서관 고객만족도\r\n\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\...
# 3      고객만족\r\n\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\r\n...
# 4      환자만족도\r\n\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\r\...
# ...                                                  ...
# 16214  Single consumer\r\n\t\t\t\t\t\t\t\t\r\n\t\t\t\...
# 16215  커버넌스\r\n\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\r\n...
# 16216  경관개선\r\n\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\r\n...
# 16217  돌봄서비스\r\n\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\r\...
# 16218  중고령자\r\n\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\r\n...
#
#                                             abstract_kor  \
# 0      Since the financial crisis occurred in 1997, t...
# 1      주(住)생활은 인간의 생존에 있어 필수적인 요소인 의식주 중 하나로, 주생활이 이루...
# 2      이 연구는 도서관의 서비스품질과 고객만족도에 대한 연구성과를 바탕으로 현장에서 용이...
# 3      본 연구는 한국과 중국의 인터넷 쇼핑몰 이용자들을 대상으로 소비자만족 결정요인들이 ...
# 4      환자의 만족도는 더 나은 의료서비스 결과물을 위한 중요 요소이기에, 환자만족도와 관...
# ...                                                  ...
# 16214  Present study performed to demonstrate the rel...
# 16215  본 연구는 군 조직성과와 관련한 선행연구들을 검토하여 조직몰입, 직무만족, 리더십,...
# 16216  The purpose of this study is to find out the i...
# 16217  본 연구는 돌봄서비스의 질에 관한 논의가 확장되고 있는 가운데 돌봄서비스 이용자의 ...
# 16218  최근 들어 중고령자의 재취업이 강조되고 있으나 이들에게 적합한 일자리가 부족하고 재...
#
#                                             abstract_eng
# 0      대부분의 지방은행들이 IMF 이후 대형금융지주회사에 흡수 통합됨으로써 현재 자생적으...
# 1      Housing is essential for life, and housing sat...
# 2      This study tries to develop the so-called LCSI...
# 3      This study examines the structural relationshi...
# 4      As patient satisfaction is a crucial component...
# ...                                                  ...
# 16214  1 성혜진, "혼밥 동기에 따른 시장세분화 연구" 한국외식경영학회 21 (21): ...
# 16215  This paper was reviewed previous studies relat...
# 16216  Abstract\r\n\t\t\t\t\t\r\n\t\t\t\t\t1. 연구의 배경 ...
# 16217  The purpose of this study is to identify clien...
# 16218  Korean government has emphasized the re-employ...
#
# [16219 rows x 7 columns]

# %%
_8_2 = pd.read_excel('./8_2_Satisfaction.xlsx')
_8_2
# Out:
#                                                    title  \
# 0                           중소기업 학습조직 구축과 활성화를 위한 실증적 연구
# 1                             중국인 의료관광 선택속성에 관한 IPA분석 연구
# 2      컨설턴트의 친사회적 서비스가 관계적 배태성, 관계신뢰, 관계만족, 장기관계지향성에 ...
# 3                청소년의 정서조절능력과 삶의 만족도와의 관계에서 대인관계역량의 매개효과
# 4                온라인 학습에서 자기주도학습능력, 상호작용 및 수업만족도의 구조적 관계
# ...                                                  ...
# 16438                            구봉 송익필의 시세계와 "독(獨)"의 경계
# 16439                                    청소년 자의식 척도의 타당화
# 16440  온플립러닝 교수법을 활용한 영상 융합 교과과정 개발연구 : 제품디자인전공에 필요한 ...
# 16441                 0-3세 영유아 교육 콘텐츠에 적용된 사용자 경험 디자인 연구
# 16442                             ‘자발적 가난’의 양상과 생태주의적 의미
#
#                                                   author  \
# 0                                                    임몽택
# 1      진문강\r\n\t\t\t\t\t\t\t\r\n                     ...
# 2      신동주\r\n\t\t\t\t\t\t\t\r\n                     ...
# 3                                                    이시연
# 4                                                    유지은
# ...                                                  ...
# 16438                              김보경 ( Bo Kyeong Kim )
# 16439  강병은(Byeongeun Kang)\r\n\t\t\t\t\t\t\t\r\n     ...
# 16440  김지윤(Jee-Youn Kim)\r\n\t\t\t\t\t\t\t\r\n       ...
# 16441  김원(Won Kim)\r\n\t\t\t\t\t\t\t\r\n             ...
# 16442                                  손민달(Son, Min-dal)
#
#                                            book  year  \
# 0                              예술인문사회융합멀티미디어논문지  2016
# 1                                       동북아관광연구  2018
# 2      디지털융복합연구(Journal of Digital Convergence)  2015
# 3      디지털융복합연구(Journal of Digital Convergence)  2017
# 4                                       기독교교육논총  2020
# ...                                         ...   ...
# 16438                                    韓國漢詩硏究  2011
# 16439                                한국심리학회지 학교  2017
# 16440  애니메이션연구(The Korean Journal of animation)  2020
# 16441                                한국디자인문화학회지  2015
# 16442                                    문학과 환경  2017
#
#                                                  keyword  \
# 0      공유비전\r\n\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\r\n...
# 1      medical tourism\r\n\t\t\t\t\t\t\t\t\r\n\t\t\t\...
# 2      컨설팅\r\n\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\r\n\...
# 3      청소년\r\n\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\r\n\...
# 4      온라인 학습\r\n\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\r...
# ...                                                  ...
# 16438  구봉\r\n\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\r\n\t...
# 16439  자의식\r\n\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\r\n\...
# 16440  영상융합 교과\r\n\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\...
# 16441  사용자 경험\r\n\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\r...
# 16442  자발적 가난\r\n\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\r...
#
#                                             abstract_kor  \
# 0      지식경영시대에 들어서면서 학습조직 활동은 개인 및 조직의 역량을 향상시키는데 매우 ...
# 1      In this study, Chinese medical tourists used t...
# 2      본 연구에서는 이미 마케팅, 심리학 분야에서 연구가 활발히 이루어지고 있는 관계배태...
# 3      본 연구는 청소년의 정서조절능력이 삶의 만족도에 미치는 영향을 파악하고, 정서조절능...
# 4      코로나 19로 인해 온라인 학습으로 대표되는 학습 방법의 변화가 보편화 되고 있는 ...
# ...                                                  ...
# 16438  龜峰 宋翼弼(1534~1599)의 시에서 ``獨``은 출현 빈도뿐만 아니라 그 시적...
# 16439  이 연구의 목적은 청소년의 자의식을 신뢰롭고 타당하게 측정하기 위하여 최근 미국에서...
# 16440  유튜브의 보급으로 영상콘텐츠를 활용한 커뮤니케이션 방식이 보편화되었다. Covid1...
# 16441  인간의 사용자 경험을 중시하는 스마트 세상으로 변화됨에 따라 사용자 경험(User ...
# 16442  자발적 가난은 산업자본주의가 낳은 인간의 무절제한 소비 만능주의에 근본적인 변화를 ...
#
#                                             abstract_eng
# 0      As we enter the age of knowledge management, l...
# 1      본 연구는 중국인 의료관광객이 대한민국 의료관광 선택의 중요도와 만족도를 측정하기 ...
# 2      This study aimed to study the relational embed...
# 3      The purpose of this study was to examine the e...
# 4      The purpose of this study was to investigate t...
# ...                                                  ...
# 16438  ``Exclusive`` in the poetry of Gubong Song Ik-...
# 16439  There is a paucity of reliable and valid measu...
# 16440  With the spread of Youtube, communication meth...
# 16441  As the world changes into a smart one that val...
# 16442  “Voluntary poverty” makes a demand for fundame...
#
# [16443 rows x 7 columns]

# %%
_9 = pd.read_excel('./8_질적_연구.xlsx')
_9
# Out:
#                                                    title  \
# 0      스포츠(교육학) 분야의 질적 연구\r\n\t\t\t \t\r\n\t\t\t \t\r...
# 1                  사회복지사인 질적연구자의 사회복지현장 연구 경험에 관한 자문화기술지
# 2                남아선호 가정에서 성장한 기혼여성의 가족 관계 경험에 관한 질적사례연구
# 3                       인터넷게임중독 청소년의 가족환경 경험에 대한 질적 사례연구
# 4                               알코올중독자의 회복경험에 대한 질적 사례연구
# ...                                                  ...
# 14900                               대한민국의 법치민주주의는 살아있는가?
# 14901                 영화 <열한시, AM 11:00>에 나타난 환상성의 시뮬라시옹
# 14902                                  국제계약법 원칙상의 변경된 승낙
# 14903     형식적 자유로부터 실질적 자유로의 접근과그 한계 -롤즈의 자유주의 이론을 중심으로-
# 14904                                  국제계약법 원칙상의 변경된 승낙
#
#                                                   author  \
# 0                                                    최의창
# 1                                                    조소연
# 2      김병영(Kim, Byoung-Young)\r\n\t\t\t\t\t\t\t\r\n  ...
# 3                                   석희정(Seok, Hee Joung)
# 4      홍미연(Hong Mi-Yeon)\r\n\t\t\t\t\t\t\t\r\n       ...
# ...                                                  ...
# 14900                               임경석(Lim, Kyung-Seok)
# 14901                                조해진 ( Hae Jin Cho )
# 14902                                                박현정
# 14903                                                이서형
# 14904                                           朴賢晶(박현정)
#
#                                                     book  year  \
# 0                   질적탐구(Journal of Qualitative Inquiry)  2016
# 1                                             한국사회복지질적연구  2019
# 2                                             한국사회복지질적연구  2011
# 3                                             한국사회복지질적연구  2016
# 4                                             한국사회복지질적연구  2018
# ...                                                  ...   ...
# 14900                                             사회와 철학  2015
# 14901                   동화와 번역(Folktale and Translation)  2014
# 14902  國際去來와 法(Dong-A Journal of International Busine...  2019
# 14903  홍익법학(The Law Reasearch institutute of Hongik U...  2017
# 14904  國際去來와 法(Dong-A Journal of International Busine...  2019
#
#                                                  keyword  \
# 0      스포츠교육학\r\n\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\r...
# 1      autoethnography\r\n\t\t\t\t\t\t\t\t\r\n\t\t\t\...
# 2      남아선호\r\n\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\r\n...
# 3      인터넷게임중독 청소년\r\n\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\...
# 4      알코올중독자\r\n\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\r...
# ...                                                  ...
# 14900  헌법재판소\r\n\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\r\...
# 14901  시뮬라크르\r\n\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\r\...
# 14902  modified acceptance\r\n\t\t\t\t\t\t\t\t\r\n\t\...
# 14903  롤즈\r\n\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\r\n\t...
# 14904  변경된 승낙\r\n\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\r...
#
#                                             abstract_kor  \
# 0      The study is to introduce the status of the qu...
# 1      The study aims to delineate the research exper...
# 2      본 연구는 가부장제 남아선호 가정에서 성장한 기혼여성의 원가족 관계 경험이 심리, ...
# 3      본 연구의 목적은 인터넷게임중독 청소년의 가족환경경험을 내부자적 관점에 근거하여 파...
# 4      본 연구의 목적은 알코올중독자들의 주관적인 회복경험을 이해하기 위한 것이다. 이러한...
# ...                                                  ...
# 14900  필자는 본고에서 1987년 6월 민주항쟁 이후 출범한 대한민국 헌법재판소가 ‘통합진...
# 14901  장르의 다양성은 영화의 질적발전과 그 의미를 같이한다는 점에서 볼 때, 2013년 ...
# 14902  CISG 제19조는 제1항에서 변경된 승낙에 대하여 청약과 승낙의 객관적 일치를 전...
# 14903  Throughout numerous revolutions and historical...
# 14904  CISG 제19조는 제1항에서 변경된 승낙에 대하여 청약과 승낙의 객관적 일치를 전...
#
#                                             abstract_eng
# 0      나는 이 글에서 스포츠교육학에서 질적 연구가 어떻게 전개되어왔으며, 현재 어떠한 상...
# 1      본 연구의 목적은 사회복지사인 질적연구자의 사회복지현장에서의 연구 경험을 기술하고 ...
# 2      This research tried to understand that women, ...
# 3      The purpose of this study is to better underst...
# 4      This study aimed to understand the subjective ...
# ...                                                  ...
# 14900  In this article I note that in June 1987 the i...
# 14901  Generally, genre films are feature films. All ...
# 14902  In commercial dealings it often happens that t...
# 14903  수많은 혁명과 인권 선언과 같은 역사적 과정을 거치면서 모든 인간은 자유롭고도 평등...
# 14904  In commercial dealings it often happens that t...
#
# [14905 rows x 7 columns]

# %%
_10 = pd.read_excel('./10_빅데이터.xlsx')
_10
# Out:
#                                         title  \
# 0     소셜 미디어 데이터 분석을 활용한 빅데이터에 대한 인식 변화 비교 분석
# 1                                   빅데이터와 통계학
# 2                     자연재해 분석을 위한 빅데이터 마이닝 기술
# 3      웹 사이언스 : 소셜 빅데이터 마이닝 기반 이슈 분석보고서 자동 생성
# 4                      바이오센싱 융합 빅데이터 컴퓨팅 아키텍처
# ...                                       ...
# 3429                         개인 맞춤형 도서 추천 시스템
# 3430          한국에서의 OSS 비즈니스 활성화를 위한 클라우드비즈니스
# 3431   정보보호 필요에 따른 클라우드 기반의 안전한 파일관리 보안솔루션 연구
# 3432               노동에 대한 보상적 정의와 기본소득의 정의 개념
# 3433                     댄스스포츠연습복 착용실태 및 생산실태
#
#                                                  author  \
# 0     윤유동 ( Youdong Yun )\r\n\t\t\t\t\t\t\t\r\n     ...
# 1     김용대\r\n\t\t\t\t\t\t\t\r\n                     ...
# 2     김영민\r\n\t\t\t\t\t\t\t\r\n                     ...
# 3     허정 ( Jeong Heo )\r\n\t\t\t\t\t\t\t\r\n        ...
# 4     고명숙\r\n\t\t\t\t\t\t\t\r\n                     ...
# ...                                                 ...
# 3429  김정준\r\n\t\t\t\t\t\t\t\r\n                     ...
# 3430  김효정\r\n\t\t\t\t\t\t\t\r\n                     ...
# 3431                                                김희철
# 3432                                  곽노완(Kwack No Wan)
# 3433  전미화(Jun, Mi Hwa)\r\n\t\t\t\t\t\t\t\r\n        ...
#
#                                                    book  year  \
# 0                             정보처리학회논문지. 소프트웨어 및 데이터 공학  2017
# 1     한국데이터정보과학회지(Journal of the Korean data & infor...  2013
# 2     한국데이터정보과학회지(Journal of the Korean data & infor...  2015
# 3                             정보처리학회논문지. 소프트웨어 및 데이터 공학  2014
# 4                             정보처리학회논문지. 소프트웨어 및 데이터 공학  2018
# ...                                                 ...   ...
# 3429                                   예술인문사회융합멀티미디어논문지  2017
# 3430                                   예술인문사회융합멀티미디어논문지  2016
# 3431                                       한국전자통신학회 논문지  2019
# 3432                         서강인문논총(Humanities journal)  2017
# 3433                                         한국디자인문화학회지  2017
#
#                                                 keyword  \
# 0     Social Media\r\n\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t...
# 1     빅데이터\r\n\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\r\n...
# 2     기계 학습\r\n\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\r\...
# 3     소셜 빅데이터 마이닝\r\n\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\...
# 4     Bio-Sensing\r\n\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\...
# ...                                                 ...
# 3429  개인맞춤형\r\n\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\r\...
# 3430  OSS\r\n\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\r\n\...
# 3431  Secure File Management Security\r\n\t\t\t\t\t\...
# 3432  기본소득\r\n\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\r\n...
# 3433  Dance Sport Practice Wear(댄스스포츠 연습복)\r\n\t\t\t...
#
#                                            abstract_kor  \
# 0     최근 모바일의 확산과 웹 서비스의 도입으로 온라인 상에 데이터가 급격히 증가하게 되...
# 1     빅데이터 시대를 맞이하여 통계학과 통계학자의 역할에 대하여 살펴본다. 빅데이터에 대...
# 2     Big data analysis for disaster have been recen...
# 3     본 논문은 지금까지의 소셜미디어 분석과 분석보고서 생성의 세 가지 문제점을 해결하기...
# 4     생체정보 컴퓨팅은 생체신호 센서와 컴퓨터 정보처리를 융합한 정보시스템에 기초하여 컴...
# ...                                                 ...
# 3429  In modern times, it is convenient for the deve...
# 3430  To drive K-ICT boom while effectively utilizin...
# 3431  In this paper, Secure file management security...
# 3432  각각의 공동체성원들에게 노동과 무관하게 무조건적으로 평등하게 지급되는 기본소득이 노...
# 3433  본 연구는 댄스스포츠연습복 개발을 목적으로, 소비자 착의실태 조사와 제품 생산실태 ...
#
#                                            abstract_eng
# 0     Recently, with the spread of smart device and ...
# 1     We investigate the roles of statistics and sta...
# 2     자연재해 빅데이터 분석은 현재 소셜 미디어 데이터 등 텍스트 데이터를 중심으로 시작...
# 3     In this paper, we propose the system for autom...
# 4     Biometric information computing is greatly inf...
# ...                                                 ...
# 3429  현대에는 정보, 통신의 발달로 편리하고 다양한 혜택을 누리고 있다. 하지만 시대는 ...
# 3430  세계 최고 수준인 한국의 인터넷 통신 인프라와 컨텐트 역량을 효과적으로 활용하면서,...
# 3431  본 연구는 안전한 파일관리 보안시스템으로 블루투스 기반 암호모듈을 연동하여 개인정보...
# 3432  Whether the basic income, which is paid equall...
# 3433  This study performed surveys on consumer cloth...
#
# [3434 rows x 7 columns]

# %%
paper_all = pd.concat([_1, _2, _3_1, _3_2, _4, _5, _6, _7, _8_1, _8_2, _9, _10], axis=0)
paper_all
# Out:
#                                                   title  \
# 0     대학생 안보의식 제고 방안 연구\r\n\t\t\t \t\r\n\t\t\t \t\r\...
# 1     자살 보도량과 심리적 변인이 대학생의 자살 의도에 미치는 영향에 관한 연구\r\n\...
# 2     장애 대학생의 지각된 스트례스와 삶의 만족간의 통합성의 매개효과분석\r\n\t\t\...
# 3     대학생 광고공모전이 광고업계 취업에 미치는 영향\r\n\t\t\t \t\r\n\t\...
# 4     개인 및 대학특성이 대학생활을 통해 형성하는 사회자본에 미치는 영향과 그 효과\r\...
# ...                                                 ...
# 3429                                   개인 맞춤형 도서 추천 시스템
# 3430                    한국에서의 OSS 비즈니스 활성화를 위한 클라우드비즈니스
# 3431             정보보호 필요에 따른 클라우드 기반의 안전한 파일관리 보안솔루션 연구
# 3432                         노동에 대한 보상적 정의와 기본소득의 정의 개념
# 3433                               댄스스포츠연습복 착용실태 및 생산실태
#
#                                                  author  \
# 0                                                   김규남
# 1     이정기(Jeong-Ki Lee)\r\n\t\t\t\t\t\t\t\r\n       ...
# 2                                                   박지순
# 3     차유철\r\n\t\t\t\t\t\t\t\r\n                     ...
# 4     박희진\r\n\t\t\t\t\t\t\t\r\n                     ...
# ...                                                 ...
# 3429  김정준\r\n\t\t\t\t\t\t\t\r\n                     ...
# 3430  김효정\r\n\t\t\t\t\t\t\t\r\n                     ...
# 3431                                                김희철
# 3432                                  곽노완(Kwack No Wan)
# 3433  전미화(Jun, Mi Hwa)\r\n\t\t\t\t\t\t\t\r\n        ...
#
#                                           book  year  \
# 0      융합보안 논문지(Convergence security journal )  2013
# 1                                   방송과 커뮤니케이션  2011
# 2                                   특수교육재활과학연구  2015
# 3     광고학연구(The Korean Journal of Advertising)  2013
# 4            한국교육(Journal of Korean Education)  2015
# ...                                        ...   ...
# 3429                          예술인문사회융합멀티미디어논문지  2017
# 3430                          예술인문사회융합멀티미디어논문지  2016
# 3431                              한국전자통신학회 논문지  2019
# 3432                서강인문논총(Humanities journal)  2017
# 3433                                한국디자인문화학회지  2017
#
#                                                 keyword  \
# 0     National security\r\n\t\t\t\t\t\t\t\t\r\n\t\t\...
# 1     자살 보도\r\n\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\r\...
# 2     삶의 만즉， 통합성\r\n\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t...
# 3                                                   325
# 4     대학생활 적응\r\n\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\...
# ...                                                 ...
# 3429  개인맞춤형\r\n\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\r\...
# 3430  OSS\r\n\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\r\n\...
# 3431  Secure File Management Security\r\n\t\t\t\t\t\...
# 3432  기본소득\r\n\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\r\n...
# 3433  Dance Sport Practice Wear(댄스스포츠 연습복)\r\n\t\t\t...
#
#                                            abstract_kor  \
# 0     국가안보란 국가와 국민의 생명과 재산을 적으로부터 지키는 것이며, 안보의식은 국민이...
# 1     최근 대학생의 자살 문제가 사회적 이슈로 부각되었다. 이에 이번 연구에서는 대학생의...
# 2     The purpose of this study was to investigate a...
# 3     취업난이 심각한 상황에서 광고업계 취업에 공모전 수상경력이 꼭 필요한 사항이라는 인...
# 4     Purpose: The purpose of this study is to explo...
# ...                                                 ...
# 3429  In modern times, it is convenient for the deve...
# 3430  To drive K-ICT boom while effectively utilizin...
# 3431  In this paper, Secure file management security...
# 3432  각각의 공동체성원들에게 노동과 무관하게 무조건적으로 평등하게 지급되는 기본소득이 노...
# 3433  본 연구는 댄스스포츠연습복 개발을 목적으로, 소비자 착의실태 조사와 제품 생산실태 ...
#
#                                            abstract_eng
# 0     요약\r\n\t\t\t\t\t\r\n\t\t\t\t\t ABSTRACT\r\n\t\...
# 1     Recently suicide among college students has em...
# 2     본 연구는 장애 대학생의 지각된 스트레스와 삶의 만족 간의 관계에서 통합성이 갖는 ...
# 3     요약\r\r\n\t\t\t\t\t\r\n\t\t\t\t\t 1. 연구배경 및 목적\...
# 4     본 연구는 우리나라 초기 성인들의 대학생활을 사회자본이론을 활용하여 이해하고자 하는...
# ...                                                 ...
# 3429  현대에는 정보, 통신의 발달로 편리하고 다양한 혜택을 누리고 있다. 하지만 시대는 ...
# 3430  세계 최고 수준인 한국의 인터넷 통신 인프라와 컨텐트 역량을 효과적으로 활용하면서,...
# 3431  본 연구는 안전한 파일관리 보안시스템으로 블루투스 기반 암호모듈을 연동하여 개인정보...
# 3432  Whether the basic income, which is paid equall...
# 3433  This study performed surveys on consumer cloth...
#
# [134541 rows x 7 columns]

# %%
paper_all = paper_all.reset_index(drop=True)
paper_all
# Out:
#                                                     title  \
# 0       대학생 안보의식 제고 방안 연구\r\n\t\t\t \t\r\n\t\t\t \t\r\...
# 1       자살 보도량과 심리적 변인이 대학생의 자살 의도에 미치는 영향에 관한 연구\r\n\...
# 2       장애 대학생의 지각된 스트례스와 삶의 만족간의 통합성의 매개효과분석\r\n\t\t\...
# 3       대학생 광고공모전이 광고업계 취업에 미치는 영향\r\n\t\t\t \t\r\n\t\...
# 4       개인 및 대학특성이 대학생활을 통해 형성하는 사회자본에 미치는 영향과 그 효과\r\...
# ...                                                   ...
# 134536                                   개인 맞춤형 도서 추천 시스템
# 134537                    한국에서의 OSS 비즈니스 활성화를 위한 클라우드비즈니스
# 134538             정보보호 필요에 따른 클라우드 기반의 안전한 파일관리 보안솔루션 연구
# 134539                         노동에 대한 보상적 정의와 기본소득의 정의 개념
# 134540                               댄스스포츠연습복 착용실태 및 생산실태
#
#                                                    author  \
# 0                                                     김규남
# 1       이정기(Jeong-Ki Lee)\r\n\t\t\t\t\t\t\t\r\n       ...
# 2                                                     박지순
# 3       차유철\r\n\t\t\t\t\t\t\t\r\n                     ...
# 4       박희진\r\n\t\t\t\t\t\t\t\r\n                     ...
# ...                                                   ...
# 134536  김정준\r\n\t\t\t\t\t\t\t\r\n                     ...
# 134537  김효정\r\n\t\t\t\t\t\t\t\r\n                     ...
# 134538                                                김희철
# 134539                                  곽노완(Kwack No Wan)
# 134540  전미화(Jun, Mi Hwa)\r\n\t\t\t\t\t\t\t\r\n        ...
#
#                                             book  year  \
# 0        융합보안 논문지(Convergence security journal )  2013
# 1                                     방송과 커뮤니케이션  2011
# 2                                     특수교육재활과학연구  2015
# 3       광고학연구(The Korean Journal of Advertising)  2013
# 4              한국교육(Journal of Korean Education)  2015
# ...                                          ...   ...
# 134536                          예술인문사회융합멀티미디어논문지  2017
# 134537                          예술인문사회융합멀티미디어논문지  2016
# 134538                              한국전자통신학회 논문지  2019
# 134539                서강인문논총(Humanities journal)  2017
# 134540                                한국디자인문화학회지  2017
#
#                                                   keyword  \
# 0       National security\r\n\t\t\t\t\t\t\t\t\r\n\t\t\...
# 1       자살 보도\r\n\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\r\...
# 2       삶의 만즉， 통합성\r\n\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t...
# 3                                                     325
# 4       대학생활 적응\r\n\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\...
# ...                                                   ...
# 134536  개인맞춤형\r\n\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\r\...
# 134537  OSS\r\n\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\r\n\...
# 134538  Secure File Management Security\r\n\t\t\t\t\t\...
# 134539  기본소득\r\n\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\r\n...
# 134540  Dance Sport Practice Wear(댄스스포츠 연습복)\r\n\t\t\t...
#
#                                              abstract_kor  \
# 0       국가안보란 국가와 국민의 생명과 재산을 적으로부터 지키는 것이며, 안보의식은 국민이...
# 1       최근 대학생의 자살 문제가 사회적 이슈로 부각되었다. 이에 이번 연구에서는 대학생의...
# 2       The purpose of this study was to investigate a...
# 3       취업난이 심각한 상황에서 광고업계 취업에 공모전 수상경력이 꼭 필요한 사항이라는 인...
# 4       Purpose: The purpose of this study is to explo...
# ...                                                   ...
# 134536  In modern times, it is convenient for the deve...
# 134537  To drive K-ICT boom while effectively utilizin...
# 134538  In this paper, Secure file management security...
# 134539  각각의 공동체성원들에게 노동과 무관하게 무조건적으로 평등하게 지급되는 기본소득이 노...
# 134540  본 연구는 댄스스포츠연습복 개발을 목적으로, 소비자 착의실태 조사와 제품 생산실태 ...
#
#                                              abstract_eng
# 0       요약\r\n\t\t\t\t\t\r\n\t\t\t\t\t ABSTRACT\r\n\t\...
# 1       Recently suicide among college students has em...
# 2       본 연구는 장애 대학생의 지각된 스트레스와 삶의 만족 간의 관계에서 통합성이 갖는 ...
# 3       요약\r\r\n\t\t\t\t\t\r\n\t\t\t\t\t 1. 연구배경 및 목적\...
# 4       본 연구는 우리나라 초기 성인들의 대학생활을 사회자본이론을 활용하여 이해하고자 하는...
# ...                                                   ...
# 134536  현대에는 정보, 통신의 발달로 편리하고 다양한 혜택을 누리고 있다. 하지만 시대는 ...
# 134537  세계 최고 수준인 한국의 인터넷 통신 인프라와 컨텐트 역량을 효과적으로 활용하면서,...
# 134538  본 연구는 안전한 파일관리 보안시스템으로 블루투스 기반 암호모듈을 연동하여 개인정보...
# 134539  Whether the basic income, which is paid equall...
# 134540  This study performed surveys on consumer cloth...
#
# [134541 rows x 7 columns]

# %%
paper_all.to_csv('./paper_all.csv')

# %%
pd.read_csv('./paper_all.csv')
# Out:
#         Unnamed: 0                                              title  \
# 0                0  대학생 안보의식 제고 방안 연구\r\n\t\t\t \t\r\n\t\t\t \t\r\...
# 1                1  자살 보도량과 심리적 변인이 대학생의 자살 의도에 미치는 영향에 관한 연구\r\n\...
# 2                2  장애 대학생의 지각된 스트례스와 삶의 만족간의 통합성의 매개효과분석\r\n\t\t\...
# 3                3  대학생 광고공모전이 광고업계 취업에 미치는 영향\r\n\t\t\t \t\r\n\t\...
# 4                4  개인 및 대학특성이 대학생활을 통해 형성하는 사회자본에 미치는 영향과 그 효과\r\...
# ...            ...                                                ...
# 134536      134536                                   개인 맞춤형 도서 추천 시스템
# 134537      134537                    한국에서의 OSS 비즈니스 활성화를 위한 클라우드비즈니스
# 134538      134538             정보보호 필요에 따른 클라우드 기반의 안전한 파일관리 보안솔루션 연구
# 134539      134539                         노동에 대한 보상적 정의와 기본소득의 정의 개념
# 134540      134540                               댄스스포츠연습복 착용실태 및 생산실태
#
#                                                    author  \
# 0                                                     김규남
# 1       이정기(Jeong-Ki Lee)\r\n\t\t\t\t\t\t\t\r\n       ...
# 2                                                     박지순
# 3       차유철\r\n\t\t\t\t\t\t\t\r\n                     ...
# 4       박희진\r\n\t\t\t\t\t\t\t\r\n                     ...
# ...                                                   ...
# 134536  김정준\r\n\t\t\t\t\t\t\t\r\n                     ...
# 134537  김효정\r\n\t\t\t\t\t\t\t\r\n                     ...
# 134538                                                김희철
# 134539                                  곽노완(Kwack No Wan)
# 134540  전미화(Jun, Mi Hwa)\r\n\t\t\t\t\t\t\t\r\n        ...
#
#                                             book  year  \
# 0        융합보안 논문지(Convergence security journal )  2013
# 1                                     방송과 커뮤니케이션  2011
# 2                                     특수교육재활과학연구  2015
# 3       광고학연구(The Korean Journal of Advertising)  2013
# 4              한국교육(Journal of Korean Education)  2015
# ...                                          ...   ...
# 134536                          예술인문사회융합멀티미디어논문지  2017
# 134537                          예술인문사회융합멀티미디어논문지  2016
# 134538                              한국전자통신학회 논문지  2019
# 134539                서강인문논총(Humanities journal)  2017
# 134540                                한국디자인문화학회지  2017
#
#                                                   keyword  \
# 0       National security\r\n\t\t\t\t\t\t\t\t\r\n\t\t\...
# 1       자살 보도\r\n\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\r\...
# 2       삶의 만즉， 통합성\r\n\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t...
# 3                                                     325
# 4       대학생활 적응\r\n\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\...
# ...                                                   ...
# 134536  개인맞춤형\r\n\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\r\...
# 134537  OSS\r\n\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\r\n\...
# 134538  Secure File Management Security\r\n\t\t\t\t\t\...
# 134539  기본소득\r\n\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\r\n...
# 134540  Dance Sport Practice Wear(댄스스포츠 연습복)\r\n\t\t\t...
#
#                                              abstract_kor  \
# 0       국가안보란 국가와 국민의 생명과 재산을 적으로부터 지키는 것이며, 안보의식은 국민이...
# 1       최근 대학생의 자살 문제가 사회적 이슈로 부각되었다. 이에 이번 연구에서는 대학생의...
# 2       The purpose of this study was to investigate a...
# 3       취업난이 심각한 상황에서 광고업계 취업에 공모전 수상경력이 꼭 필요한 사항이라는 인...
# 4       Purpose: The purpose of this study is to explo...
# ...                                                   ...
# 134536  In modern times, it is convenient for the deve...
# 134537  To drive K-ICT boom while effectively utilizin...
# 134538  In this paper, Secure file management security...
# 134539  각각의 공동체성원들에게 노동과 무관하게 무조건적으로 평등하게 지급되는 기본소득이 노...
# 134540  본 연구는 댄스스포츠연습복 개발을 목적으로, 소비자 착의실태 조사와 제품 생산실태 ...
#
#                                              abstract_eng
# 0       요약\r\n\t\t\t\t\t\r\n\t\t\t\t\t ABSTRACT\r\n\t\...
# 1       Recently suicide among college students has em...
# 2       본 연구는 장애 대학생의 지각된 스트레스와 삶의 만족 간의 관계에서 통합성이 갖는 ...
# 3       요약\r\r\n\t\t\t\t\t\r\n\t\t\t\t\t 1. 연구배경 및 목적\...
# 4       본 연구는 우리나라 초기 성인들의 대학생활을 사회자본이론을 활용하여 이해하고자 하는...
# ...                                                   ...
# 134536  현대에는 정보, 통신의 발달로 편리하고 다양한 혜택을 누리고 있다. 하지만 시대는 ...
# 134537  세계 최고 수준인 한국의 인터넷 통신 인프라와 컨텐트 역량을 효과적으로 활용하면서,...
# 134538  본 연구는 안전한 파일관리 보안시스템으로 블루투스 기반 암호모듈을 연동하여 개인정보...
# 134539  Whether the basic income, which is paid equall...
# 134540  This study performed surveys on consumer cloth...
#
# [134541 rows x 8 columns]
